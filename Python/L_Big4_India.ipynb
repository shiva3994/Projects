# %%
import ast
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from pathlib import Path

folder = Path(r"C:\Users\Shiva Thakur\OneDrive\Desktop\Github\Projects\Python\E_Big4_India")

data_dict = {f.stem: pd.read_csv(f) for f in folder.glob("*.csv")}

# %%
clients = data_dict['Clients']

print("Shape:", clients.shape)
clients.head()
# Out:
# Shape: (120000, 5)
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %% [markdown]
# ##### Names of all tables

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### # **Type A — Load & explore**

# %% [markdown]
# ##### 1. Load `clients.csv` and display the first 5 rows and the shape.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %% [markdown]
# ##### 2. Load `employees.csv` and check data types with `.info()`.

# %%
data_dict['Employees'].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Employee_ID  250000 non-null  int64
#  1   Company      250000 non-null  str
#  2   Department   250000 non-null  str
#  3   Role         250000 non-null  str
#  4   Age          250000 non-null  int64
#  5   Salary       250000 non-null  int64
#  6   JoinDate     250000 non-null  str
# dtypes: int64(3), str(4)
# memory usage: 13.4 MB

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### 3. Load `projects.csv` and check for missing values per column.

# %%
data_dict['Projects'].isnull().sum()
# Out:
# Project_ID     0
# Company        0
# Client_ID      0
# Employee_ID    0
# Technology     0
# Budget         0
# Status         0
# dtype: int64

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### 4. Load `offices.csv` and list all column names.

# %%
data_dict['Office_Locations'].columns

print('Column names for the table Office_Locations are :', data_dict['Office_Locations'].columns)
# Out:
# Column names for the table Office_Locations are : Index(['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees'], dtype='str')

# %% [markdown]
# ##### 5. Load `technologies.csv` and check for duplicate rows with `.duplicated()`.

# %%
data_dict['Technologies'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149995    False
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# Length: 150000, dtype: bool

# %% [markdown]
# ##### **Type B — Column selection**

# %% [markdown]
# ##### 6. From `clients`, select just `Company` and `Industry`.

# %%
data_dict['Clients'][['Company','Industry']]
# Out:
#         Company    Industry
# 0         Wipro      Retail
# 1           TCS  Healthcare
# 2         Wipro  Healthcare
# 3           TCS  Healthcare
# 4       Infosys      Retail
# ...         ...         ...
# 119995  HCLTech  Healthcare
# 119996      TCS     Telecom
# 119997    Wipro     Banking
# 119998  Infosys  Healthcare
# 119999  Infosys     Telecom
#
# [120000 rows x 2 columns]

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### 7. From `employees`, select `Employee_ID`, `Role`, and `Salary`.

# %%
data_dict['Employees'][['Employee_ID','Role','Salary']]
# Out:
#         Employee_ID    Role  Salary
# 0                 1      QA   91806
# 1                 2      SE   14827
# 2                 3      BA  121727
# 3                 4     SSE   88985
# 4                 5      SE   35904
# ...             ...     ...     ...
# 249995       249996  DevOps   29369
# 249996       249997      QA   65865
# 249997       249998      QA   48007
# 249998       249999      SE   65756
# 249999       250000      QA  113592
#
# [250000 rows x 3 columns]

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### 8. From `projects`, select `Project_ID`, `Technology`, and `Status`.

# %%
data_dict['Projects'][['Project_ID','Technology','Status']]
# Out:
#         Project_ID Technology       Status
# 0                1      Azure  In Progress
# 1                2      Azure      On Hold
# 2                3        AWS      On Hold
# 3                4       Java      On Hold
# 4                5        GCP  In Progress
# ...            ...        ...          ...
# 179995      179996       Java    Completed
# 179996      179997        GCP    Completed
# 179997      179998        AWS    Completed
# 179998      179999        GCP  In Progress
# 179999      180000     Python  In Progress
#
# [180000 rows x 3 columns]

# %% [markdown]
# ##### 10. From `financials`, select `Company`, `Year`, and `Revenue`.

# %%
data_dict['Company_Financials'][['Company', 'Year', 'Revenue']]
# Out:
#         Company  Year  Revenue
# 0           TCS  2015     4812
# 1           TCS  2025     7712
# 2           TCS  2018     1234
# 3       HCLTech  2018     5357
# 4       Infosys  2026     6374
# ...         ...   ...      ...
# 119995  Infosys  2017     8410
# 119996      TCS  2015     5936
# 119997  Infosys  2016     3715
# 119998  HCLTech  2025     1416
# 119999  HCLTech  2022     3698
#
# [120000 rows x 3 columns]

# %% [markdown]
# ##### **Type C — Filtering rows**

# %% [markdown]
# ##### 11. Filter `clients` to only rows where `Industry == 'Retail'`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Clients'].loc[data_dict['Clients']['Industry'] == 'Retail'].head()
# Out:
#     Client_ID  Company Industry Country  ContractValue
# 0           1    Wipro   Retail   India       39728043
# 4           5  Infosys   Retail      UK       15392192
# 6           7    Wipro   Retail      UK       39845758
# 13         14  Infosys   Retail  Canada       26940688
# 16         17    Wipro   Retail      UK       13172681

# %% [markdown]
# ##### 12. Filter `employees` to only rows where `Department == 'AI'`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Employees'].loc[data_dict['Employees']['Department'] == 'AI'].head()
# Out:
#     Employee_ID  Company Department    Role  Age  Salary    JoinDate
# 0             1    Wipro         AI      QA   50   91806  11-04-2020
# 9            10  Infosys         AI      QA   49   27540  20-04-2020
# 18           19  Infosys         AI  DevOps   57  104793  29-04-2020
# 22           23  HCLTech         AI     SSE   33   57850  03-05-2020
# 24           25      TCS         AI      PM   35   92132  05-05-2020

# %% [markdown]
# ##### 13. Filter `projects` to only rows where `Status == 'In Progress'`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Projects'].loc[data_dict['Projects']['Status'] == 'In Progress'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 4           5      TCS     114709       100718        GCP  4313680
# 6           7  HCLTech     113542       186129       Java  5171519
# 7           8      TCS      72965        39418       Java  6434833
# 9          10  HCLTech      59848        86628        SAP   133948
#
#         Status
# 0  In Progress
# 4  In Progress
# 6  In Progress
# 7  In Progress
# 9  In Progress

# %% [markdown]
# ##### 14. Filter `offices` to only rows where `Country == 'India'`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations'].loc[data_dict['Office_Locations']['Country'] == 'India'].head()
# Out:
#     Office_ID  Company Country State     City  Employees
# 1           2  HCLTech   India    TS     Pune       7143
# 5           6      TCS   India    TN  Kolkata       8237
# 7           8    Wipro   India    WB     Pune      13110
# 11         12  Infosys   India    TS     Pune       5469
# 16         17    Wipro   India    KA  Kolkata      12903

# %% [markdown]
# ##### 15. Filter `financials` to only rows where `Year == 2021`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].loc[data_dict['Company_Financials']['Year'] == 2021 ].head()
# Out:
#     Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 7              8      TCS  2021      Q1     5603    1561     201349
# 14            15    Wipro  2021      Q3     1884     944     198682
# 42            43      TCS  2021      Q3     8254    1248     160888
# 60            61  Infosys  2021      Q2     1485    1342     145591
# 70            71    Wipro  2021      Q1     7111    2441      99828

# %% [markdown]
# ##### **Type D — `.value_counts()`**

# %% [markdown]
# ##### 16. Count how many clients fall into each `Industry`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients']['Industry'].value_counts()
# Out:
# Industry
# Healthcare       24115
# Manufacturing    24041
# Retail           24018
# Banking          23965
# Telecom          23861
# Name: count, dtype: int64

# %% [markdown]
# ##### 17. Count how many employees fall into each `Department`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees']['Department'].value_counts()
# Out:
# Department
# Support        31545
# Finance        31396
# AI             31325
# Engineering    31222
# HR             31214
# Sales          31211
# Cloud          31157
# IT             30930
# Name: count, dtype: int64

# %% [markdown]
# ##### 18. Count how many projects fall into each `Status`.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects']['Status'].value_counts()
# Out:
# Status
# Completed      60121
# On Hold        60032
# In Progress    59847
# Name: count, dtype: int64

# %% [markdown]
# ##### 19. Count how many offices exist per `Company`.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations']['Company'].value_counts()
# Out:
# Company
# Infosys    25163
# TCS        25010
# HCLTech    24963
# Wipro      24864
# Name: count, dtype: int64

# %% [markdown]
# ##### 20. Count how many technologies fall into each `Technology` name.

# %%
data_dict['Technologies'].head()
# Out:
#    Technology_ID  Company Technology  Project_ID  Popularity
# 0              1  HCLTech        SAP      153468       57.75
# 1              2    Wipro        SAP       48952       57.73
# 2              3  HCLTech      Azure      146403       78.35
# 3              4      TCS     Python       39073       75.26
# 4              5      TCS      Azure       50553       85.76

# %%
data_dict['Technologies']['Technology'].value_counts()
# Out:
# Technology
# AWS       25132
# Java      25092
# Python    25029
# Azure     24962
# SAP       24923
# GCP       24862
# Name: count, dtype: int64

# %% [markdown]
# ##### **Type A — Single aggregate**

# %% [markdown]
# ##### 1. Calculate the average `Salary` in `employees`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees']['Salary'].mean()

print(f'Average salary of employees is: {data_dict['Employees']['Salary'].mean():.2f}')
# Out:
# Average salary of employees is: 78895.84

# %% [markdown]
# ##### 2. Calculate the total `ContractValue` in `clients`.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients']['ContractValue'].sum()

print(f'The total contract value in clients is :{data_dict['Clients']['ContractValue'].sum():.2f}')
# Out:
# The total contract value in clients is :2999443706423.00

# %% [markdown]
# ##### 3. Find the maximum `Budget` in `projects`.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects']['Budget'].max()

print(f'Maximum Budget in projects is: {data_dict['Projects']['Budget'].max():.2f}')
# Out:
# Maximum Budget in projects is: 9999902.00

# %% [markdown]
# ##### 4. Find the minimum `Profit` in `financials`.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials']['Profit'].min()

print(f'The minimum profit in finance is : {data_dict['Company_Financials']['Profit'].min():.2f}')
# Out:
# The minimum profit in finance is : 80.00

# %% [markdown]
# ##### 5. Count the total number of rows in `offices`.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
len(data_dict['Office_Locations'])

print(f'Total number of rows in office table are : {len(data_dict['Office_Locations'])}')
# Out:
# Total number of rows in office table are : 100000

# %% [markdown]
# ##### **Type B — `.groupby()` + `.count()` / `.size()`**

# %% [markdown]
# ##### 6. Group `employees` by `Department` and count employees in each.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].groupby('Department').size()
# Out:
# Department
# AI             31325
# Cloud          31157
# Engineering    31222
# Finance        31396
# HR             31214
# IT             30930
# Sales          31211
# Support        31545
# dtype: int64

# %% [markdown]
# ##### 7. Group `clients` by `Industry` and count clients in each.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients'].groupby('Industry').size()
# Out:
# Industry
# Banking          23965
# Healthcare       24115
# Manufacturing    24041
# Retail           24018
# Telecom          23861
# dtype: int64

# %% [markdown]
# ##### 8. Group `projects` by `Status` and count projects in each.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].groupby('Status').size()
# Out:
# Status
# Completed      60121
# In Progress    59847
# On Hold        60032
# dtype: int64

# %% [markdown]
# ##### 9. Group `offices` by `Country` and count offices in each.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations'].groupby('Country').size()
# Out:
# Country
# Canada     19919
# Germany    19994
# India      20019
# UK         20068
# USA        20000
# dtype: int64

# %% [markdown]
# ##### 10. Group `financials` by `Company` and count records in each.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].groupby('Company').size()
# Out:
# Company
# HCLTech    29753
# Infosys    29963
# TCS        30186
# Wipro      30098
# dtype: int64

# %% [markdown]
# ##### **Type C — `.groupby()` + `.mean()` / `.sum()`**

# %% [markdown]
# ##### 11. Group `employees` by `Department` and find average `Salary`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].groupby('Department')['Salary'].mean().round(2)
# Out:
# Department
# AI             79439.99
# Cloud          78825.29
# Engineering    78711.19
# Finance        78867.22
# HR             78975.95
# IT             78833.82
# Sales          78837.07
# Support        78676.08
# Name: Salary, dtype: float64

# %% [markdown]
# ##### 12. Group `clients` by `Industry` and find total `ContractValue`.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients'].groupby('Industry')['ContractValue'].mean()
# Out:
# Industry
# Banking          2.499614e+07
# Healthcare       2.489478e+07
# Manufacturing    2.509016e+07
# Retail           2.495520e+07
# Telecom          2.504116e+07
# Name: ContractValue, dtype: float64

# %% [markdown]
# ##### 13. Group `projects` by `Technology` and find average `Budget`.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].groupby('Technology').size()
# Out:
# Technology
# AWS       29989
# Azure     30103
# GCP       30033
# Java      29899
# Python    30038
# SAP       29938
# dtype: int64

# %%
data_dict['Projects'].groupby('Technology')['Budget'].mean()
# Out:
# Technology
# AWS       5.031285e+06
# Azure     5.003498e+06
# GCP       5.021909e+06
# Java      5.028624e+06
# Python    5.034717e+06
# SAP       5.038316e+06
# Name: Budget, dtype: float64

# %% [markdown]
# ##### 14. Group `financials` by `Company` and find total `Revenue`.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].groupby('Company').size()
# Out:
# Company
# HCLTech    29753
# Infosys    29963
# TCS        30186
# Wipro      30098
# dtype: int64

# %%
data_dict['Company_Financials'].groupby('Company')['Revenue'].mean()
# Out:
# Company
# HCLTech    4905.237959
# Infosys    4910.797650
# TCS        4908.652885
# Wipro      4880.339059
# Name: Revenue, dtype: float64

# %% [markdown]
# ##### 15. Group `technologies` by `Technology` and find average `Popularity`.

# %%
data_dict['Technologies'].head()
# Out:
#    Technology_ID  Company Technology  Project_ID  Popularity
# 0              1  HCLTech        SAP      153468       57.75
# 1              2    Wipro        SAP       48952       57.73
# 2              3  HCLTech      Azure      146403       78.35
# 3              4      TCS     Python       39073       75.26
# 4              5      TCS      Azure       50553       85.76

# %%
data_dict['Technologies'].groupby('Technology')['Popularity'].mean()
# Out:
# Technology
# AWS       74.988675
# Azure     74.957781
# GCP       74.961102
# Java      74.878793
# Python    74.860119
# SAP       74.989803
# Name: Popularity, dtype: float64

# %% [markdown]
# ##### **Type D — `.groupby()` + `.agg()` (multiple stats at once)**

# %% [markdown]
# ##### 16. Group `employees` by `Department` and get both mean and max `Salary` in one `.agg()`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].groupby('Department')['Salary'].agg(['mean', 'max']).round(2)
# Out:
#                  mean     max
# Department
# AI           79439.99  149997
# Cloud        78825.29  149993
# Engineering  78711.19  149994
# Finance      78867.22  150000
# HR           78975.95  149998
# IT           78833.82  149994
# Sales        78837.07  149996
# Support      78676.08  150000

# %% [markdown]
# ##### 17. Group `clients` by `Industry` and get both sum and count of `ContractValue`.

# %%
data_dict['Clients'].groupby('Industry')['ContractValue'].agg(['sum','count']).round(2)
# Out:
#                         sum  count
# Industry
# Banking        599032568528  23965
# Healthcare     600337613772  24115
# Manufacturing  603192574026  24041
# Retail         599373926642  24018
# Telecom        597507023455  23861

# %% [markdown]
# ##### 18. Group `projects` by `Status` and get min, max, and mean `Budget`.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].groupby('Status')['Budget'].agg(['min','max','mean']).round(2)
# Out:
#                min      max        mean
# Status
# Completed    50028  9999892  5032316.90
# In Progress  50117  9999902  5032367.76
# On Hold      50603  9999770  5014446.16

# %% [markdown]
# ##### 19. Group `financials` by `Company` and get sum of `Revenue` and sum of `Profit`.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].groupby('Company').agg({'Revenue':'sum','Profit':'sum'}).round(2)
# Out:
#            Revenue    Profit
# Company
# HCLTech  145945545  38386932
# Infosys  147142230  38631594
# TCS      148172596  38854753
# Wipro    146888445  38847877

# %% [markdown]
# ##### 20. Group `offices` by `Company` and get count of offices and sum of `Employees`.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations'].groupby('Company')['Employees'].agg(['sum']).round(2)
#Single condition aggrigate
# Out:
#                sum
# Company
# HCLTech  187341532
# Infosys  189072363
# TCS      187591141
# Wipro    186057600

# %%
data_dict['Office_Locations'].groupby('Company').agg({'Office_ID':'count','Employees':'sum'}).round(2)
#Multi condition aggrigate
# Out:
#          Office_ID  Employees
# Company
# HCLTech      24963  187341532
# Infosys      25163  189072363
# TCS          25010  187591141
# Wipro        24864  186057600

# %% [markdown]
# ##### **Type A — `.sort_values()` basics**

# %% [markdown]
# ##### 1. Sort `employees` by `Salary` descending.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].sort_values( by = 'Salary', ascending = False ).head()
# Out:
#         Employee_ID  Company Department Role  Age  Salary    JoinDate
# 241621       241622      TCS    Finance  SSE   45  150000  24-10-2681
# 81995         81996    Wipro    Finance   DS   35  150000  09-10-2244
# 129810       129811    Wipro    Support   QA   26  150000  08-09-2375
# 182728       182729      TCS         HR   QA   48  149998  27-07-2520
# 46759         46760  HCLTech    Support   DS   21  149998  19-04-2148

# %% [markdown]
# ##### 2. Sort `clients` by `ContractValue` ascending.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients'].sort_values( by = 'ContractValue', ascending = True ).head()
# Out:
#         Client_ID  Company       Industry Country  ContractValue
# 70866       70867  HCLTech         Retail   India         100589
# 34495       34496    Wipro        Telecom   India         101160
# 65988       65989  Infosys        Banking  Canada         101164
# 100382     100383    Wipro        Telecom      UK         101593
# 23859       23860      TCS  Manufacturing      UK         101873

# %% [markdown]
# ##### 3. Sort `projects` by `Budget` descending.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].sort_values( by = 'Budget', ascending = False ).head()
# Out:
#         Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 53884        53885  HCLTech      72801       230397      Azure  9999902
# 32513        32514    Wipro      25174       143144        SAP  9999892
# 117146      117147    Wipro       4039        49372      Azure  9999770
# 22244        22245  HCLTech      65861       119656       Java  9999724
# 80257        80258  HCLTech      99498       186314       Java  9999704
#
#              Status
# 53884   In Progress
# 32513     Completed
# 117146      On Hold
# 22244       On Hold
# 80257       On Hold

# %% [markdown]
# ##### 4. Sort `financials` by `Revenue` descending.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].sort_values( by = 'Revenue', ascending = False ).head()
# Out:
#        Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 29205         29206  HCLTech  2021      Q3     9000     577      54520
# 46482         46483    Wipro  2024      Q2     9000     457     131498
# 98008         98009    Wipro  2021      Q3     9000     861     243738
# 55534         55535      TCS  2022      Q2     9000    1857     165982
# 79751         79752    Wipro  2019      Q3     9000     552     204409

# %% [markdown]
# ##### 5. Sort `technologies` by `Popularity` descending.

# %%
data_dict['Technologies'].head()
# Out:
#    Technology_ID  Company Technology  Project_ID  Popularity
# 0              1  HCLTech        SAP      153468       57.75
# 1              2    Wipro        SAP       48952       57.73
# 2              3  HCLTech      Azure      146403       78.35
# 3              4      TCS     Python       39073       75.26
# 4              5      TCS      Azure       50553       85.76

# %%
data_dict['Technologies'].sort_values( by = 'Popularity', ascending = False ).head()
# Out:
#         Technology_ID  Company Technology  Project_ID  Popularity
# 76232           76233      TCS        SAP       58196       100.0
# 38032           38033  Infosys        AWS      153757       100.0
# 119121         119122      TCS     Python      161474       100.0
# 105442         105443  Infosys        AWS        3357       100.0
# 85034           85035  Infosys        AWS      157353       100.0

# %% [markdown]
# ##### **Type B — `.head()` / `.nlargest()`**

# %% [markdown]
# ##### 6. Find the top 5 highest-paid employees using `.nlargest()`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].nlargest(5, 'Salary')
# Out:
#         Employee_ID  Company Department Role  Age  Salary    JoinDate
# 81995         81996    Wipro    Finance   DS   35  150000  09-10-2244
# 129810       129811    Wipro    Support   QA   26  150000  08-09-2375
# 241621       241622      TCS    Finance  SSE   45  150000  24-10-2681
# 20041         20042      TCS    Support  SSE   52  149998  23-02-2075
# 46759         46760  HCLTech    Support   DS   21  149998  19-04-2148

# %% [markdown]
# ##### 7. Find the top 3 clients by `ContractValue`.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients'].nlargest(3,'ContractValue')
# Out:
#        Client_ID  Company       Industry  Country  ContractValue
# 88432      88433    Wipro  Manufacturing  Germany       49999295
# 44704      44705  Infosys  Manufacturing   Canada       49999084
# 70332      70333  Infosys        Telecom       UK       49998424

# %% [markdown]
# ##### 8. Find the top 5 projects by `Budget`.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].nlargest(5, 'Budget')
# Out:
#         Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 53884        53885  HCLTech      72801       230397      Azure  9999902
# 32513        32514    Wipro      25174       143144        SAP  9999892
# 117146      117147    Wipro       4039        49372      Azure  9999770
# 22244        22245  HCLTech      65861       119656       Java  9999724
# 80257        80258  HCLTech      99498       186314       Java  9999704
#
#              Status
# 53884   In Progress
# 32513     Completed
# 117146      On Hold
# 22244       On Hold
# 80257       On Hold

# %% [markdown]
# ##### 9. Find the top 3 rows by `Revenue` in `financials`.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].nlargest(3, 'Revenue')
# Out:
#        Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 13479         13480      TCS  2021      Q3     9000     234     151837
# 18666         18667  HCLTech  2016      Q4     9000    1646      98913
# 29205         29206  HCLTech  2021      Q3     9000     577      54520

# %% [markdown]
# ##### 10. Find the top 5 rows by `Popularity` in `technologies`.

# %%
data_dict['Technologies'].head()
# Out:
#    Technology_ID  Company Technology  Project_ID  Popularity
# 0              1  HCLTech        SAP      153468       57.75
# 1              2    Wipro        SAP       48952       57.73
# 2              3  HCLTech      Azure      146403       78.35
# 3              4      TCS     Python       39073       75.26
# 4              5      TCS      Azure       50553       85.76

# %%
data_dict['Technologies'].nlargest(5, 'Popularity')
# Out:
#        Technology_ID  Company Technology  Project_ID  Popularity
# 19293          19294    Wipro     Python      158484       100.0
# 36989          36990    Wipro        SAP      162284       100.0
# 38032          38033  Infosys        AWS      153757       100.0
# 44807          44808  Infosys        AWS       55895       100.0
# 53464          53465    Wipro        GCP      143095       100.0

# %% [markdown]
# ##### **Type C — Multi-column sort**

# %% [markdown]
# ##### 11. Sort `employees` by `Department` ascending, then `Salary` descending.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees'].sort_values(by=['Department', 'Salary'], ascending=[True, False]).head()
# Out:
#         Employee_ID  Company Department    Role  Age  Salary    JoinDate
# 94979         94980      TCS         AI  DevOps   37  149997  27-04-2280
# 114160       114161    Wipro         AI      SE   45  149996  02-11-2332
# 25808         25809  HCLTech         AI      BA   43  149986  08-12-2090
# 156249       156250  Infosys         AI      BA   21  149985  27-01-2448
# 108350       108351    Wipro         AI      DS   36  149983  06-12-2316

# %% [markdown]
# ##### 12. Sort `clients` by `Industry` ascending, then `ContractValue` descending.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients'].sort_values(by=['Industry','ContractValue'],ascending=[True,False]).head()
# Out:
#        Client_ID  Company Industry Country  ContractValue
# 54195      54196  HCLTech  Banking   India       49997280
# 51887      51888      TCS  Banking      UK       49997145
# 98283      98284  Infosys  Banking      UK       49996725
# 52701      52702    Wipro  Banking  Canada       49993871
# 52463      52464  Infosys  Banking   India       49992681

# %% [markdown]
# ##### 13. Sort `projects` by `Status` ascending, then `Budget` descending.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict['Projects'].sort_values(by=['Status','Budget'],ascending=[True,False]).head()
# Out:
#         Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 32513        32514    Wipro      25174       143144        SAP  9999892
# 37306        37307    Wipro      93980        28632        AWS  9999590
# 159986      159987  HCLTech      55109       138762      Azure  9999459
# 76619        76620      TCS      77876       188274        SAP  9999306
# 84507        84508    Wipro      36866        67262     Python  9999073
#
#            Status
# 32513   Completed
# 37306   Completed
# 159986  Completed
# 76619   Completed
# 84507   Completed

# %% [markdown]
# ##### 14. Sort `financials` by `Company` ascending, then `Year` descending.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
data_dict['Company_Financials'].sort_values(by=['Company','Year'],ascending=[True,False]).head()
# Out:
#      Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 138           139  HCLTech  2026      Q3     7394    1195     181195
# 159           160  HCLTech  2026      Q4     7125     703     179847
# 211           212  HCLTech  2026      Q1     5512    1359     142181
# 329           330  HCLTech  2026      Q3     8580     148     146562
# 336           337  HCLTech  2026      Q1     3062    2204     104353

# %% [markdown]
# ##### 15. Sort `offices` by `Country` ascending, then `City` ascending.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations'].sort_values(by=['Country','City'],ascending=[True,False]).head()
# Out:
#     Office_ID Company Country State  City  Employees
# 0           1   Wipro  Canada    KA  Pune      10757
# 49         50     TCS  Canada    TS  Pune      10264
# 72         73   Wipro  Canada    MH  Pune      13956
# 74         75     TCS  Canada    TN  Pune       2251
# 77         78   Wipro  Canada    KA  Pune       4098

# %% [markdown]
# ##### **Type D — String methods (`.str`)**

# %%
# Method	                            What it does
# .str.upper() / .str.lower()	        Convert case
# .str.len()	                        Character count of each string
# .str.strip()	                        Remove leading/trailing whitespace
# .str.replace('old', 'new')	        Replace substrings
# .str.contains('text')	                Boolean — does the string contain this?
# .str.split(',')	                    Split into a list
# .str.startswith() / .str.endswith()	Boolean checks
# .str.slice(0, 3) or [0:3]	            Substring
# .str.title()	                        Capitalize Each Word
# .str.cat(sep=', ')	                Join strings together
# .str.extract(r'(\d+)')	            Pull out text matching a regex pattern

# %% [markdown]
# ##### 16. Convert all `Company` values in `clients` to uppercase using `.str.upper()`.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients']['Company'].str.upper()
# Out:
# 0           WIPRO
# 1             TCS
# 2           WIPRO
# 3             TCS
# 4         INFOSYS
#            ...
# 119995    HCLTECH
# 119996        TCS
# 119997      WIPRO
# 119998    INFOSYS
# 119999    INFOSYS
# Name: Company, Length: 120000, dtype: str

# %% [markdown]
# ##### 17. Create a new column with the character length of each `Role` in `employees`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate
# 0            1    Wipro           AI   QA   50   91806  11-04-2020
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020

# %%
data_dict['Employees']['Role_len'] = data_dict['Employees']['Role'].str.len()

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate  Role_len
# 0            1    Wipro           AI   QA   50   91806  11-04-2020         2
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020         2
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020         2
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020         3
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020         2

# %% [markdown]
# ##### 18. Combine `City` and `Country` from `offices` into one column separated by a comma.

# %%
data_dict['Office_Locations'].head()
# Out:
#    Office_ID  Company Country State       City  Employees
# 0          1    Wipro  Canada    KA       Pune      10757
# 1          2  HCLTech   India    TS       Pune       7143
# 2          3    Wipro      UK    TS    Chennai       8807
# 3          4  HCLTech  Canada    WB    Chennai       3058
# 4          5    Wipro  Canada    TN  Bengaluru       8998

# %%
data_dict['Office_Locations']['City_and_Country'] = data_dict['Office_Locations']['City'].str.cat(data_dict['Office_Locations']['Country'], sep=', ')

# %%
data_dict['Office_Locations']['City_and_Country']
# Out:
# 0             Pune, Canada
# 1              Pune, India
# 2              Chennai, UK
# 3          Chennai, Canada
# 4        Bengaluru, Canada
#                ...
# 99995       Bengaluru, USA
# 99996       Chennai, India
# 99997    Hyderabad, Canada
# 99998       Chennai, India
# 99999         Kolkata, USA
# Name: City_and_Country, Length: 100000, dtype: str

# %% [markdown]
# ##### 19. Extract the first 3 letters of each `Technology` name in `technologies`.

# %%
data_dict['Technologies'].head()
# Out:
#    Technology_ID  Company Technology  Project_ID  Popularity
# 0              1  HCLTech        SAP      153468       57.75
# 1              2    Wipro        SAP       48952       57.73
# 2              3  HCLTech      Azure      146403       78.35
# 3              4      TCS     Python       39073       75.26
# 4              5      TCS      Azure       50553       85.76

# %%
data_dict['Technologies']['Technology'].str.extract(r'(^.{3})')

# To extract the first 3 characters using regex, use ^
# {3} (where ^ means start of string, and .{3} means any 3 characters)
# Out:
#           0
# 0       SAP
# 1       SAP
# 2       Azu
# 3       Pyt
# 4       Azu
# ...     ...
# 149995  AWS
# 149996  AWS
# 149997  GCP
# 149998  Jav
# 149999  Azu
#
# [150000 rows x 1 columns]

# %% [markdown]
# ##### 20. Strip any leading/trailing whitespace from `Company` names using `.str.strip()`.

# %%
data_dict['Clients'].head()
# Out:
#    Client_ID  Company    Industry Country  ContractValue
# 0          1    Wipro      Retail   India       39728043
# 1          2      TCS  Healthcare   India       41065784
# 2          3    Wipro  Healthcare   India       32180187
# 3          4      TCS  Healthcare  Canada        7905343
# 4          5  Infosys      Retail      UK       15392192

# %%
data_dict['Clients']['Company'].str.strip()
# Out:
# 0           Wipro
# 1             TCS
# 2           Wipro
# 3             TCS
# 4         Infosys
#            ...
# 119995    HCLTech
# 119996        TCS
# 119997      Wipro
# 119998    Infosys
# 119999    Infosys
# Name: Company, Length: 120000, dtype: str

# %%
### Python

# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# Method	                            What it does
# .str.upper() / .str.lower()	        Convert case
# .str.len()	                        Character count of each string
# .str.strip()	                        Remove leading/trailing whitespace
# .str.replace('old', 'new')	        Replace substrings
# .str.contains('text')	                Boolean — does the string contain this?
# .str.split(',')	                    Split into a list
# .str.startswith() / .str.endswith()	Boolean checks
# .str.slice(0, 3) or [0:3]	            Substring
# .str.title()	                        Capitalize Each Word
# .str.cat(sep=', ')	                Join strings together
# .str.extract(r'(\d+)')	            Pull out text matching a regex pattern

# %% [markdown]
# ##### **Type A — Basic `.merge()` (2 DataFrames)**

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %% [markdown]
# ##### 1. Merge `projects` and `clients` on `Client_ID` to add each client's `Company` name to the projects table.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict_merge1 = data_dict['Clients'].merge(data_dict['Projects'][['Client_ID', 'Company']],
                   on='Client_ID',
                   how='left')

data_dict_merge1.head()
# Out:
#    Client_ID Company_x    Industry Country  ContractValue Company_y
# 0          1     Wipro      Retail   India       39728043     Wipro
# 1          2       TCS  Healthcare   India       41065784       NaN
# 2          3     Wipro  Healthcare   India       32180187   Infosys
# 3          4       TCS  Healthcare  Canada        7905343   HCLTech
# 4          4       TCS  Healthcare  Canada        7905343   HCLTech

# %% [markdown]
# ##### 2. Merge `employees` and `projects` on `Employee_ID` to add each employee's `Role` to the projects table.

# %%
data_dict_merge2 =  data_dict['Projects'].merge(data_dict['Employees'][['Employee_ID', 'Role']],
                    on='Employee_ID',
                    how='left')

data_dict_merge2.head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status    Role
# 0  In Progress      PM
# 1      On Hold      PM
# 2      On Hold  DevOps
# 3      On Hold      SE
# 4  In Progress      DS

# %% [markdown]
# ##### 3. Merge `financials` and `offices` on `Company` to see revenue alongside office city.

# %%
company_revenue = data_dict['Company_Financials'].groupby('Company')['Revenue'].sum().reset_index()

data_dict_merge3 = data_dict['Office_Locations'].merge(company_revenue, on='Company', how='left')
data_dict_merge3.head()
# Out:
#    Office_ID  Company Country State       City  Employees   City_and_Country  \
# 0          1    Wipro  Canada    KA       Pune      10757       Pune, Canada
# 1          2  HCLTech   India    TS       Pune       7143        Pune, India
# 2          3    Wipro      UK    TS    Chennai       8807        Chennai, UK
# 3          4  HCLTech  Canada    WB    Chennai       3058    Chennai, Canada
# 4          5    Wipro  Canada    TN  Bengaluru       8998  Bengaluru, Canada
#
#      Revenue
# 0  146888445
# 1  145945545
# 2  146888445
# 3  145945545
# 4  146888445

# %% [markdown]
# ##### 4. Merge `projects` and `technologies` on `Project_ID` to see project status alongside technology.

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict_merge4 = data_dict['Technologies'].merge(data_dict['Projects'][['Project_ID', 'Technology']],
    on='Project_ID',
    how='left'
)

data_dict_merge4.head()
# Out:
#    Technology_ID  Company Technology_x  Project_ID  Popularity Technology_y
# 0              1  HCLTech          SAP      153468       57.75         Java
# 1              2    Wipro          SAP       48952       57.73         Java
# 2              3  HCLTech        Azure      146403       78.35         Java
# 3              4      TCS       Python       39073       75.26       Python
# 4              5      TCS        Azure       50553       85.76          GCP

# %% [markdown]
# ##### 5. Merge `clients` and `financials` on `Company` to compare `ContractValue` to `Revenue`.

# %%
data_dict['Company_Financials'].head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758

# %%
print(data_dict['Clients'].columns.tolist())
# Out:
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']

# %%
print(data_dict['Company_Financials']['Company'].duplicated().sum())
print(data_dict['Clients']['Company'].duplicated().sum())
# Out:
# 119996
# 119996

# %%
print(data_dict['Company_Financials'].shape)
print(data_dict['Clients'].shape)
print(data_dict['Company_Financials']['Company'].value_counts())
print(data_dict['Clients']['Company'].value_counts())
# Out:
# (120000, 7)
# (120000, 5)
# Company
# TCS        30186
# Wipro      30098
# Infosys    29963
# HCLTech    29753
# Name: count, dtype: int64
# Company
# Infosys    30179
# HCLTech    30052
# Wipro      29928
# TCS        29841
# Name: count, dtype: int64

# %%
# Aggregate contract value per company (choose the summary that fits your analysis)
clients_agg = (
    data_dict['Clients']
    .groupby('Company', as_index=False)['ContractValue']
    .sum()  # or .mean(), depending on what you want to compare
)

data_dict_merge5 = data_dict['Company_Financials'].merge(
    clients_agg,
    on='Company',
    how='left'
)

data_dict_merge5.head()
# Out:
#    Financial_ID  Company  Year Quarter  Revenue  Profit  Employees  \
# 0             1      TCS  2015      Q3     4812     994      86579
# 1             2      TCS  2025      Q1     7712     210      57811
# 2             3      TCS  2018      Q2     1234    2378     102124
# 3             4  HCLTech  2018      Q4     5357     106     248916
# 4             5  Infosys  2026      Q4     6374    1218      90758
#
#    ContractValue
# 0   752415545056
# 1   752415545056
# 2   752415545056
# 3   746722909774
# 4   753146001192

# %% [markdown]
# ##### **Type B — Merge + filter**

# %% [markdown]
# ##### 6. Merge `projects` and `clients`, then filter to only clients in the `'Retail'` industry.

# %%
print(list(data_dict.keys()))
# Out:
# ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']

# %%
data_dict['Clients']
# Out:
#         Client_ID  Company    Industry  Country  ContractValue
# 0               1    Wipro      Retail    India       39728043
# 1               2      TCS  Healthcare    India       41065784
# 2               3    Wipro  Healthcare    India       32180187
# 3               4      TCS  Healthcare   Canada        7905343
# 4               5  Infosys      Retail       UK       15392192
# ...           ...      ...         ...      ...            ...
# 119995     119996  HCLTech  Healthcare    India       22623683
# 119996     119997      TCS     Telecom   Canada       41321352
# 119997     119998    Wipro     Banking       UK       26511992
# 119998     119999  Infosys  Healthcare      USA       38927776
# 119999     120000  Infosys     Telecom  Germany       35154422
#
# [120000 rows x 5 columns]

# %%
data_dict1 = data_dict['Projects'].merge(
    data_dict['Clients'],
    on='Client_ID',   # swap for the actual shared column if different
    how='left'
)

data_dict1 = data_dict1[data_dict1['Industry'] == 'Retail']

data_dict1.head()
# Out:
#     Project_ID Company_x  Client_ID  Employee_ID Technology   Budget  \
# 11          12       TCS     117027        94326       Java  8541902
# 12          13     Wipro      30997        19863        AWS  3602900
# 17          18       TCS      18159       141780        GCP  5795346
# 22          23   Infosys      49167       105650        SAP   120782
# 32          33       TCS      19757        26540       Java  4213237
#
#          Status Company_y Industry  Country  ContractValue
# 11  In Progress     Wipro   Retail      USA       48355816
# 12      On Hold   HCLTech   Retail    India       44949970
# 17    Completed   HCLTech   Retail  Germany       34857990
# 22  In Progress       TCS   Retail   Canada       24881576
# 32  In Progress   HCLTech   Retail    India       19115547

# %% [markdown]
# ##### 7. Merge `employees` and `projects`, then filter to only projects with `Status == 'In Progress'`.

# %%
data_dict['Employees'].head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate  Role_len
# 0            1    Wipro           AI   QA   50   91806  11-04-2020         2
# 1            2    Wipro      Finance   SE   21   14827  12-04-2020         2
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020         2
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020         3
# 4            5  Infosys      Finance   SE   25   35904  15-04-2020         2

# %%
data_dict['Projects'].head()
# Out:
#    Project_ID  Company  Client_ID  Employee_ID Technology   Budget  \
# 0           1    Wipro      32252       195820      Azure  8646817
# 1           2    Wipro      21042        69871      Azure  6633547
# 2           3  HCLTech      89295       148126        AWS  5647221
# 3           4  Infosys      54119       115503       Java  7970162
# 4           5      TCS     114709       100718        GCP  4313680
#
#         Status
# 0  In Progress
# 1      On Hold
# 2      On Hold
# 3      On Hold
# 4  In Progress

# %%
data_dict2 = data_dict['Projects'].merge(data_dict['Employees'],
                                         on = 'Employee_ID',
                                         how = 'left')

data_dict2 = data_dict2[data_dict2['Status'] == 'In Progress']

data_dict2.head()
# Out:
#    Project_ID Company_x  Client_ID  Employee_ID Technology   Budget  \
# 0           1     Wipro      32252       195820      Azure  8646817
# 4           5       TCS     114709       100718        GCP  4313680
# 6           7   HCLTech     113542       186129       Java  5171519
# 7           8       TCS      72965        39418       Java  6434833
# 9          10   HCLTech      59848        86628        SAP   133948
#
#         Status Company_y Department    Role  Age  Salary    JoinDate  Role_len
# 0  In Progress     Wipro    Finance      PM   25  118913  30-05-2556         2
# 4  In Progress   Infosys      Sales      DS   35  140011  12-01-2296         2
# 6  In Progress   Infosys         IT      QA   22  105776  17-11-2529         2
# 7  In Progress       TCS    Finance  DevOps   27   38204  13-03-2128         6
# 9  In Progress       TCS    Support      BA   48  144396  15-06-2257         2

# %% [markdown]
# ##### 8. Merge `offices` and `financials`, then filter to only offices in `'India'`.

# %%
print(list(data_dict['Office_Locations'].columns))
print(list(data_dict['Company_Financials'].columns))
# Out:
# ['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees', 'City_and_Country']
# ['Financial_ID', 'Company', 'Year', 'Quarter', 'Revenue', 'Profit', 'Employees']

# %%
print(data_dict['Company_Financials']['Company'].duplicated().sum())
print(data_dict['Office_Locations']['Company'].duplicated().sum())
# Out:
# 119996
# 99996

# %%
print(data_dict['Office_Locations'].shape)
print(data_dict['Office_Locations'].columns.tolist())
print(data_dict['Office_Locations'].head(10))
# Out:
# (100000, 7)
# ['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees', 'City_and_Country']
#    Office_ID  Company Country State       City  Employees   City_and_Country
# 0          1    Wipro  Canada    KA       Pune      10757       Pune, Canada
# 1          2  HCLTech   India    TS       Pune       7143        Pune, India
# 2          3    Wipro      UK    TS    Chennai       8807        Chennai, UK
# 3          4  HCLTech  Canada    WB    Chennai       3058    Chennai, Canada
# 4          5    Wipro  Canada    TN  Bengaluru       8998  Bengaluru, Canada
# 5          6      TCS   India    TN    Kolkata       8237     Kolkata, India
# 6          7  HCLTech  Canada    TS    Kolkata       8742    Kolkata, Canada
# 7          8    Wipro   India    WB       Pune      13110        Pune, India
# 8          9      TCS     USA    WB  Hyderabad       9553     Hyderabad, USA
# 9         10      TCS  Canada    TS    Chennai       1895    Chennai, Canada

# %%
# Filter offices to India first (shrinks the table, and matches the task order)
india_offices = data_dict['Office_Locations'][data_dict['Office_Locations']['Country'] == 'India']

# Aggregate financials to one row per company
financials_agg = (
    data_dict['Company_Financials']
    .groupby('Company', as_index=False)
    .agg({'Revenue': 'sum', 'Profit': 'sum', 'Employees': 'sum'})  # adjust as needed
)

# Safe merge: many offices (India only) × one row per company
data_dict3 = india_offices.merge(
    financials_agg,
    on='Company',
    how='left',
    validate='many_to_one'  # will raise immediately if financials_agg still has dupes
)

data_dict3.head()
# Out:
#    Office_ID  Company Country State     City  Employees_x City_and_Country  \
# 0          2  HCLTech   India    TS     Pune         7143      Pune, India
# 1          6      TCS   India    TN  Kolkata         8237   Kolkata, India
# 2          8    Wipro   India    WB     Pune        13110      Pune, India
# 3         12  Infosys   India    TS     Pune         5469      Pune, India
# 4         17    Wipro   India    KA  Kolkata        12903   Kolkata, India
#
#      Revenue    Profit  Employees_y
# 0  145945545  38386932   4471007590
# 1  148172596  38854753   4528184263
# 2  146888445  38847877   4517995143
# 3  147142230  38631594   4509984234
# 4  146888445  38847877   4517995143

# %% [markdown]
# ##### 9. Merge `projects` and `technologies`, then filter to only `Technology == 'Azure'`.

# %%
print(list(data_dict['Projects'].columns))
print(list(data_dict['Technologies'].columns))
# Out:
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']
# ['Technology_ID', 'Company', 'Technology', 'Project_ID', 'Popularity']

# %%
print(data_dict['Projects']['Technology'].duplicated().sum())
print(data_dict['Technologies']['Technology'].duplicated().sum())
# Out:
# 179994
# 149994

# %%
# Filter to Azure first — shrinks the table before merging
azure_tech = data_dict['Technologies'][data_dict['Technologies']['Technology'] == 'Azure']

# Merge in project details — one Project row per Azure_tech row
data_dict4 = azure_tech.merge(
    data_dict['Projects'],
    on='Project_ID',
    how='left',
    validate='many_to_one'   # will error immediately if Projects turns out to have dupes too
)

data_dict4.head()
# Out:
#    Technology_ID Company_x Technology_x  Project_ID  Popularity Company_y  \
# 0              3   HCLTech        Azure      146403       78.35     Wipro
# 1              5       TCS        Azure       50553       85.76   Infosys
# 2             11     Wipro        Azure       61585       97.33       TCS
# 3             18       TCS        Azure       99552       85.18     Wipro
# 4             22       TCS        Azure      117522       80.69     Wipro
#
#    Client_ID  Employee_ID Technology_y   Budget       Status
# 0      36192       146452         Java  5333226    Completed
# 1      66973       182062          GCP  5887141      On Hold
# 2      53506       151372          AWS  7980012  In Progress
# 3      76547        26298         Java  5179635    Completed
# 4     104794       137459        Azure  6233382  In Progress

# %% [markdown]
# ##### 10. Merge `clients` and `projects`, then filter to only projects with `Budget > 5000000`.

# %%
print(data_dict['Clients'].columns.tolist())
print(data_dict['Projects'].columns.tolist())
print(data_dict['Clients']['Client_ID'].duplicated().sum())
print(data_dict['Projects']['Client_ID'].duplicated().sum())
# Out:
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']
# 0
# 86587

# %%
data_dict5 = data_dict['Projects'].merge(
    data_dict['Clients'],
    on='Client_ID',
    how='left',
    validate='many_to_one'
)

data_dict5 = data_dict5[data_dict5['Budget'] > 5000000]
data_dict5.head()
# Out:
#    Project_ID Company_x  Client_ID  Employee_ID Technology   Budget  \
# 0           1     Wipro      32252       195820      Azure  8646817
# 1           2     Wipro      21042        69871      Azure  6633547
# 2           3   HCLTech      89295       148126        AWS  5647221
# 3           4   Infosys      54119       115503       Java  7970162
# 5           6       TCS      91805        24244        AWS  9438406
#
#         Status Company_y       Industry  Country  ContractValue
# 0  In Progress   HCLTech     Healthcare       UK       37353571
# 1      On Hold       TCS        Telecom   Canada       46381259
# 2      On Hold   HCLTech     Healthcare      USA       35518385
# 3      On Hold   Infosys     Healthcare  Germany       26194180
# 5    Completed       TCS  Manufacturing  Germany       24585436

# %% [markdown]
# ##### **Type C — Merge + groupby**

# %% [markdown]
# ##### 11. Merge `projects` and `clients`, then find total `Budget` per client `Industry`.

# %%
print(list(data_dict['Projects'].columns))
print(list(data_dict['Clients'].columns))
# Out:
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']

# %%
data_dict11 = data_dict['Projects'].merge(
    data_dict['Clients'],
    on='Client_ID',
    how='left',
    validate='many_to_one'
)

budget_by_industry = data_dict11.groupby('Industry', as_index=False)['Budget'].sum()

budget_by_industry
# Out:
#         Industry        Budget
# 0        Banking  180873598514
# 1     Healthcare  182920959429
# 2  Manufacturing  181057777032
# 3         Retail  180386547229
# 4        Telecom  179508387588

# %% [markdown]
# ##### 12. Merge `employees` and `projects`, then count projects per employee `Department`.

# %%
print(list(data_dict['Employees'].columns))
print(list(data_dict['Projects'].columns))
# Out:
# ['Employee_ID', 'Company', 'Department', 'Role', 'Age', 'Salary', 'JoinDate', 'Role_len']
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']

# %%
data_dict12 = data_dict['Projects'].merge(
    data_dict['Employees'],
    on = 'Employee_ID',
    how = 'left',
    validate='many_to_one')

Projects_by_dept = data_dict12.groupby('Department', as_index=False)['Project_ID'].sum()

Projects_by_dept
# Out:
#     Department  Project_ID
# 0           AI  2043229371
# 1        Cloud  2029503242
# 2  Engineering  2021178586
# 3      Finance  2041194707
# 4           HR  2027783124
# 5           IT  2000238517
# 6        Sales  2003626115
# 7      Support  2033336338

# %% [markdown]
# ##### 13. Merge `offices` and `financials`, then find average `Revenue` per office `Country`.

# %%
print(list(data_dict['Office_Locations'].columns))
print(list(data_dict['Company_Financials'].columns))
# Out:
# ['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees', 'City_and_Country']
# ['Financial_ID', 'Company', 'Year', 'Quarter', 'Revenue', 'Profit', 'Employees']

# %%
# Aggregate financials to one row per company first (avoids many-to-many)
financials_agg = (
    data_dict['Company_Financials']
    .groupby('Company', as_index=False)['Revenue'].mean()
    .rename(columns={'Revenue': 'Avg_Revenue'})
)

# Safe merge: many offices × one row per company
data_dict13 = data_dict['Office_Locations'].merge(
    financials_agg,
    on='Company',
    how='left',
    validate='many_to_one'
)

# Now average that per office Country
revenue_by_country = data_dict13.groupby('Country', as_index=False)['Avg_Revenue'].mean()
revenue_by_country
# Out:
#    Country  Avg_Revenue
# 0   Canada  4901.279599
# 1  Germany  4901.318643
# 2    India  4901.145476
# 3       UK  4901.381493
# 4      USA  4901.375357

# %% [markdown]
# ##### 14. Merge `projects` and `technologies`, then find average `Popularity` per project `Status`.

# %%
print(list(data_dict['Projects'].columns))
print(list(data_dict['Technologies'].columns))
# Out:
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']
# ['Technology_ID', 'Company', 'Technology', 'Project_ID', 'Popularity']

# %%
data_dict14 = data_dict['Technologies'].merge(
    data_dict['Projects'],
    on= 'Project_ID',
    how= 'left')

popularity_by_status = data_dict14.groupby('Status',as_index=False)['Popularity'].mean()

popularity_by_status
# Out:
#         Status  Popularity
# 0    Completed   75.024477
# 1  In Progress   74.925182
# 2      On Hold   74.868319

# %% [markdown]
# ##### 15. Merge `clients` and `projects`, then find average `Budget` per client `Country`.

# %%
print(list(data_dict['Clients'].columns))
print(list(data_dict['Projects'].columns))
# Out:
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']

# %%
data_dict15 = data_dict['Projects'].merge(
    data_dict['Clients'],
    on = 'Client_ID',
    how = 'left'
)

budget_by_country = data_dict15.groupby('Country',as_index=False)['Budget'].mean()

budget_by_country
# Out:
#    Country        Budget
# 0   Canada  5.001735e+06
# 1  Germany  5.038221e+06
# 2    India  5.030301e+06
# 3       UK  5.023012e+06
# 4      USA  5.038552e+06

# %% [markdown]
# ##### **Type D — `how='left'` + finding unmatched rows**

# %% [markdown]
# ##### 16. Left-merge `clients` with `projects` to find clients with no associated project (`Project_ID` is `NaN`).

# %%
print(list(data_dict['Projects'].columns))
print(list(data_dict['Clients'].columns))
# Out:
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']

# %%
data_dict16 = data_dict['Clients'].merge(
    data_dict['Projects'],
    on='Client_ID',
    how='left',
    validate='one_to_many'
)

clients_no_projects = data_dict16[data_dict16['Project_ID'].isna()]

clients_no_projects.head()
# Out:
#     Client_ID Company_x    Industry Country  ContractValue  Project_ID  \
# 1           2       TCS  Healthcare   India       41065784         NaN
# 8           6   HCLTech  Healthcare  Canada        3606105         NaN
# 17         11     Wipro     Telecom  Canada         939266         NaN
# 34         19   HCLTech     Telecom      UK       44100520         NaN
# 40         23   Infosys     Telecom     USA       45994153         NaN
#
#    Company_y  Employee_ID Technology  Budget Status
# 1        NaN          NaN        NaN     NaN    NaN
# 8        NaN          NaN        NaN     NaN    NaN
# 17       NaN          NaN        NaN     NaN    NaN
# 34       NaN          NaN        NaN     NaN    NaN
# 40       NaN          NaN        NaN     NaN    NaN

# %% [markdown]
# ##### 17. Left-merge `employees` with `projects` to find employees not assigned to any project.

# %%
print(list(data_dict['Employees'].columns))
print(list(data_dict['Projects'].columns))
# Out:
# ['Employee_ID', 'Company', 'Department', 'Role', 'Age', 'Salary', 'JoinDate', 'Role_len']
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']

# %%
data_dict17 = data_dict['Employees'].merge(
    data_dict['Projects'],
    on='Employee_ID',
    how='left',
    validate='one_to_many'
)

emp_no_projects = data_dict17[data_dict17['Project_ID'].isna()]

emp_no_projects.head()
# Out:
#     Employee_ID Company_x Department Role  Age  Salary    JoinDate  Role_len  \
# 1             2     Wipro    Finance   SE   21   14827  12-04-2020         2
# 2             3     Wipro    Finance   BA   49  121727  13-04-2020         2
# 8             9       TCS      Cloud  SSE   41  137059  19-04-2020         3
# 9            10   Infosys         AI   QA   49   27540  20-04-2020         2
# 10           11   Infosys         IT   SE   58   23219  21-04-2020         2
#
#     Project_ID Company_y  Client_ID Technology  Budget Status
# 1          NaN       NaN        NaN        NaN     NaN    NaN
# 2          NaN       NaN        NaN        NaN     NaN    NaN
# 8          NaN       NaN        NaN        NaN     NaN    NaN
# 9          NaN       NaN        NaN        NaN     NaN    NaN
# 10         NaN       NaN        NaN        NaN     NaN    NaN

# %% [markdown]
# ##### 18. Left-merge `financials` with `offices` (on Company) to find companies with financials but no office listed.

# %%
print(list(data_dict['Company_Financials'].columns))
print(list(data_dict['Office_Locations'].columns))
# Out:
# ['Financial_ID', 'Company', 'Year', 'Quarter', 'Revenue', 'Profit', 'Employees']
# ['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees', 'City_and_Country']

# %%
financial_companies = data_dict['Company_Financials'][['Company']].drop_duplicates()
office_companies = data_dict['Office_Locations'][['Company']].drop_duplicates()

data_dict18 = financial_companies.merge(
    office_companies,
    on='Company',
    how='left',
    indicator=True
)

companies_no_office = data_dict18[data_dict18['_merge'] == 'left_only']

companies_no_office
# Out:
# Empty DataFrame
# Columns: [Company, _merge]
# Index: []

# %%
print(sorted(data_dict['Company_Financials']['Company'].unique()))
print(sorted(data_dict['Office_Locations']['Company'].unique()))
# Out:
# ['HCLTech', 'Infosys', 'TCS', 'Wipro']
# ['HCLTech', 'Infosys', 'TCS', 'Wipro']

# %% [markdown]
# ##### 19. Left-merge `technologies` with `projects` to find technology entries with no matching project.

# %%
print(list(data_dict['Technologies'].columns))
print(list(data_dict['Projects'].columns))
# Out:
# ['Technology_ID', 'Company', 'Technology', 'Project_ID', 'Popularity']
# ['Project_ID', 'Company', 'Client_ID', 'Employee_ID', 'Technology', 'Budget', 'Status']

# %%
data_dict19 = data_dict['Technologies'].merge(
    data_dict['Projects'],
    on= 'Project_ID',
    how= 'left')

company_noproject = data_dict19[data_dict19['Status'].isna()]

company_noproject
# Out:
# Empty DataFrame
# Columns: [Technology_ID, Company_x, Technology_x, Project_ID, Popularity, Company_y, Client_ID, Employee_ID, Technology_y, Budget, Status]
# Index: []

# %% [markdown]
# ##### 20. Left-merge `offices` with `financials` (on Company) to find offices with no matching financial record.

# %%
print(list(data_dict['Office_Locations'].columns))
print(list(data_dict['Company_Financials'].columns))
# Out:
# ['Office_ID', 'Company', 'Country', 'State', 'City', 'Employees', 'City_and_Country']
# ['Financial_ID', 'Company', 'Year', 'Quarter', 'Revenue', 'Profit', 'Employees']

# %%
financial_companies = data_dict['Company_Financials'][['Company']].drop_duplicates()

data_dict20 = data_dict['Office_Locations'].merge(
    financial_companies,
    on='Company',
    how='left',
    indicator=True
)

offices_no_financials = data_dict20[data_dict20['_merge'] == 'left_only']

offices_no_financials
# Out:
# Empty DataFrame
# Columns: [Office_ID, Company, Country, State, City, Employees, City_and_Country, _merge]
# Index: []

# %% [markdown]
# ##### **Type A — Boolean filtering against an overall stat**

# %% [markdown]
# ##### 1. Find employees whose `Salary` is above `employees['Salary'].mean()`.

# %%
print(list(data_dict['Employees'].columns))
# Out:
# ['Employee_ID', 'Company', 'Department', 'Role', 'Age', 'Salary', 'JoinDate', 'Role_len']

# %%
avg_salary = data_dict['Employees']['Salary'].mean()

high_earners = data_dict['Employees'][data_dict['Employees']['Salary'] > avg_salary]

high_earners.head()
# Out:
#    Employee_ID  Company   Department Role  Age  Salary    JoinDate  Role_len
# 0            1    Wipro           AI   QA   50   91806  11-04-2020         2
# 2            3    Wipro      Finance   BA   49  121727  13-04-2020         2
# 3            4    Wipro  Engineering  SSE   43   88985  14-04-2020         3
# 5            6  HCLTech        Cloud  SSE   44  144114  16-04-2020         3
# 6            7      TCS           HR   DS   44  128945  17-04-2020         2

# %% [markdown]
# ##### 2. Find clients whose `ContractValue` is above `clients['ContractValue'].mean()`.

# %%
print(list(data_dict['Clients'].columns))
# Out:
# ['Client_ID', 'Company', 'Industry', 'Country', 'ContractValue']

# %%
avg_contractvalue = data_dict['Clients']['ContractValue'].mean()

high_contractvalue =

# %% [markdown]
# ##### 3. Find projects whose `Budget` is above `projects['Budget'].mean()`.

# %% [markdown]
# ##### 4. Find financial records where `Revenue` is above `financials['Revenue'].mean()`.

# %% [markdown]
# ##### 5. Find technologies where `Popularity` is above `technologies['Popularity'].mean()`.

# %%
# # ['Clients', 'Company_Financials', 'Employees', 'Office_Locations', 'Projects', 'Technologies']



##### **Type B — GroupBy + filter (pandas' HAVING equivalent)**
##### 6. Find departments where average `Salary` exceeds 60000 (`.groupby().filter()` or `.groupby().mean()` + boolean mask).
##### 7. Find industries where total `ContractValue` exceeds 100000000.
##### 8. Find project statuses where average `Budget` exceeds 5000000.
##### 9. Find companies where total `Revenue` exceeds 50000.
##### 10. Find technologies where average `Popularity` exceeds 50.

##### **Type C — `.apply()` / `np.where()` for categorization**
##### 11. Create a column labeling each employee `'Senior'` if `Age > 40`, else `'Junior'`.
##### 12. Create a column labeling each client `'High Value'` if `ContractValue > 20000000`, else `'Standard'`.
##### 13. Create a column labeling each project `'Big Budget'` if `Budget > 5000000`, else `'Small Budget'`.
##### 14. Create a column labeling each financial record `'Profitable'` if `Profit > 0`, else `'Loss'`.
##### 15. Create a column labeling each technology `'Popular'` if `Popularity > 50`, else `'Niche'`.

##### **Type D — `.transform()` for per-group comparison**
##### 16. Find employees earning more than their department's average salary using `.groupby('Department')['Salary'].transform('mean')`.
##### 17. Find clients whose `ContractValue` is above their industry's average using `.transform()`.
##### 18. Find projects whose `Budget` is above their status group's average using `.transform()`.
##### 19. Find financial records above their company's average revenue using `.transform()`.
##### 20. Find technologies above their company's average popularity using `.transform()`.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import os, glob
import pandas as pd

# --- 1. Connection (set up once) ---
server = r"LAPTOP-A70F1ENF\SHIVASQLEXPRESS"
database = "P_Big4_India"
driver = "ODBC Driver 17 for SQL Server"

params = quote_plus(
    f"DRIVER={{{driver}}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
)
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# --- 2. Load all CSVs into a dict ---
folder_path = r"C:\Users\Shiva Thakur\OneDrive\Desktop\Github\Practice\Daily Python\E_Big4_India"
data_dict = {
    os.path.splitext(os.path.basename(f))[0]: pd.read_csv(f)
    for f in glob.glob(os.path.join(folder_path, "*.csv"))
}

# --- 3. Push each DataFrame to its own table ---
for table_name, df in data_dict.items():
    df.to_sql(table_name, engine, if_exists="replace", index=False)
    print(f"Loaded table: {table_name} ({df.shape[0]} rows)")

# --- 4. Sanity check ---
for table_name in data_dict.keys():
    print(f"\n--- {table_name} ---")
    print(pd.read_sql(f"SELECT TOP 5 * FROM [{table_name}];", engine))
