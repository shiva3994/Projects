# %%
import ast
import pandas as pd
import numpy as nb
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ##### **Loading & Exploring**

# %% [markdown]
# ##### 1. Load the CSV into a DataFrame and display the first 5 rows.

# %%
df = pd.read_csv('Data_CO2_emission.csv')

# %%
df.head(5)
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# ##### 2. Check the shape of the DataFrame (rows, columns).

# %%
print('Size of dataset is :', df.size)
print('Shape of dataset is :', df.shape)
# Out:
# Size of dataset is : 7525
# Shape of dataset is : (215, 35)

# %% [markdown]
# ##### 3. List all column names.

# %%
print('Names of columns are :', df.columns.tolist())
# Out:
# Names of columns are : ['Country Name', 'country_code', 'Region', 'Indicator Name', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2019.1']

# %% [markdown]
# ##### 4. Check the data types of each column using `.info()`.

# %%
df.dtypes
# Out:
# Country Name          str
# country_code          str
# Region                str
# Indicator Name        str
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2019.1            float64
# dtype: object

# %%
df.describe()
# Out:
#              1990        1991        1992        1993        1994        1995  \
# count  185.000000  186.000000  189.000000  189.000000  189.000000  190.000000
# mean     4.404504    4.290648    4.174834    4.085472    4.045067    4.136628
# std      5.577460    5.577411    5.362451    5.385712    5.464233    5.510400
# min      0.001183    0.001158    0.001130    0.001100    0.001071    0.001043
# 25%      0.434249    0.452759    0.471380    0.448535    0.406659    0.423225
# 50%      1.914543    1.941825    2.012212    1.867589    1.830972    1.832534
# 75%      6.910335    6.497471    6.482311    6.430944    6.337175    6.360589
# max     30.195189   31.778496   29.632441   33.122025   36.466263   37.102174
#
#              1996        1997        1998        1999  ...        2011  \
# count  190.000000  190.000000  189.000000  189.000000  ...  191.000000
# mean     4.211147    4.250716    4.282809    4.265652  ...    4.392175
# ...

# %% [markdown]
# ##### 5. Check how many missing (null) values exist in each column.

# %%
df.isnull().sum()
# Out:
# Country Name       0
# country_code       0
# Region             0
# Indicator Name     0
# 1990              30
# 1991              29
# 1992              26
# 1993              26
# 1994              26
# 1995              25
# 1996              25
# 1997              25
# 1998              26
# 1999              26
# 2000              25
# 2001              25
# 2002              24
# 2003              24
# 2004              24
# 2005              24
# 2006              24
# 2007              24
# 2008              24
# 2009              24
# 2010              24
# 2011              24
# 2012              24
# 2013              24
# 2014              24
# 2015              24
# 2016              24
# 2017              24
# 2018              24
# 2019              24
# 2019.1            24
# dtype: int64

# %% [markdown]
# ##### **Basic Filtering & Selection**

# %% [markdown]
# ##### 6. Select just the `Country Name` and `Region` columns.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
df[['Country Name','Region']]
# Out:
#      Country Name                      Region
# 0           Aruba   Latin America & Caribbean
# 1     Afghanistan                  South Asia
# 2          Angola          Sub-Saharan Africa
# 3         Albania       Europe & Central Asia
# 4         Andorra       Europe & Central Asia
# ..            ...                         ...
# 210         Samoa         East Asia & Pacific
# 211   Yemen, Rep.  Middle East & North Africa
# 212  South Africa          Sub-Saharan Africa
# 213        Zambia          Sub-Saharan Africa
# 214      Zimbabwe          Sub-Saharan Africa
#
# [215 rows x 2 columns]

# %% [markdown]
# ##### 7. Filter the DataFrame to show only rows where `Region` == `'South Asia'`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
df[df['Region'] == 'South Asia']
# Out:
#     Country Name country_code      Region  \
# 1    Afghanistan          AFG  South Asia
# 17    Bangladesh          BGD  South Asia
# 29        Bhutan          BTN  South Asia
# 88         India          IND  South Asia
# 112    Sri Lanka          LKA  South Asia
# 123     Maldives          MDV  South Asia
# 145        Nepal          NPL  South Asia
# 149     Pakistan          PAK  South Asia
#
#                              Indicator Name      1990      1991      1992  \
# 1    CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 17   CO2 emissions (metric tons per capita)  0.111658  0.102558  0.109461
# 29   CO2 emissions (metric tons per capita)  0.150716  0.243156  0.224498
# 88   CO2 emissions (metric tons per capita)  0.645362  0.681306  0.688755
# 112  CO2 emissions (metric tons per capita)  0.221635  0.227535  0.295994
# 123  CO2 emissions (metric tons per capita)  0.716978  0.696430  0.973458
# ...

# %% [markdown]
# ##### 8. Find all rows for `'India'`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
df[df['Country Name'] == 'India']
# Out:
#    Country Name country_code      Region  \
# 88        India          IND  South Asia
#
#                             Indicator Name      1990      1991      1992  \
# 88  CO2 emissions (metric tons per capita)  0.645362  0.681306  0.688755
#
#         1993      1994      1995  ...      2011      2012      2013      2014  \
# 88  0.702337  0.725358  0.765476  ...  1.405068  1.508508  1.539948  1.657231
#
#         2015      2016      2017      2018     2019   2019.1
# 88  1.647152  1.657396  1.733361  1.812696  1.79762  1.79762
#
# [1 rows x 35 columns]

# %% [markdown]
# ##### 9. Drop the duplicate `2019` column (there are two — keep only one).

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
col = ['2019.1']
df = df.drop(columns = col)

# %%
print(df.columns.to_list())
# Out:
# ['Country Name', 'country_code', 'Region', 'Indicator Name', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %% [markdown]
# ##### 10. Count how many unique countries are in the dataset.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
#df.value_counts('Country Name')

print('Number of unique countries is :', df['Country Name'].nunique())
# df['Country Name'].nunique()
# Out:
# Number of unique countries is : 215

# %% [markdown]
# ##### **Simple Calculations**

# %% [markdown]
# ##### 11. Find the average CO2 emission value for the year `2019` across all countries.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
avg_emission = df['2019'].mean()
print(f'Average CO2 emission for 2019 is : {avg_emission:.2f}')
# f prefix tells Python this is an f-string, which lets you embed variable values directly inside a string using curly braces {}
# .2f means "format as a fixed-point (decimal) number, rounded to 2 decimal places.

# {value:.0f} → rounds to a whole number, no decimals
# {value:,.2f} → adds comma separators for thousands (e.g. 1,234.56)
# {value:.2%} → formats a decimal as a percentage (e.g. 0.418 becomes 41.80%)
# Out:
# Average CO2 emission for 2019 is : 4.12

# %% [markdown]
# ##### 12. Find which country had the highest CO2 emission in `2019`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
highest_country_2019 = df.loc[df['2019'].idxmax(), 'Country Name']
print(f'Country with highest CO2 emission in 2019 is {highest_country_2019}')

# df['2019'].idxmax() — finds the index label of the row with the maximum value in the 2019 column (not the value itself, but where it is).
# df.loc[..., 'Country'] — uses that index to look up the corresponding value in the Country column.
# Out:
# Country with highest CO2 emission in 2019 is Qatar

# %% [markdown]
# ##### 13. Find which country had the lowest CO2 emission in `2019` (excluding missing values).

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
Lowest_CO2_2019 = df.loc[df['2019'].idxmin(), 'Country Name']
print(f'Lowest CO2 emission for a country was {Lowest_CO2_2019}')

#idxmin() (like idxmax(), mean(), min(), max(), etc.) automatically excludes NaN values by default in pandas.


# One edge case to be aware of: if the 2019 column is entirely NaN (no valid values at all),
# idxmin() will raise a ValueError since there's nothing to compare.
# If you want to be extra explicit about excluding missing values (e.g., for a teacher or portfolio reviewer to see the intent clearly),
# you could optionally write:

# valid_2019 = df.dropna(subset=['2019'])
# Lowest_CO2_2019 = valid_2019.loc[valid_2019['2019'].idxmin(), 'Country Name']
# print(f'Lowest CO2 emission for a country was {Lowest_CO2_2019}')
# Out:
# Lowest CO2 emission for a country was Congo, Dem. Rep.

# %% [markdown]
# ##### 14. Count how many countries belong to each `Region` using `.value_counts()`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
df.value_counts('Region')
# Out:
# Region
# Europe & Central Asia         56
# Sub-Saharan Africa            48
# Latin America & Caribbean     42
# East Asia & Pacific           37
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: count, dtype: int64

# %% [markdown]
# ##### 15. Calculate the total (sum) of CO2 emissions for `2019` grouped by `Region`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
co2_by_region_2019 = df.groupby('Region')['2019'].sum().reset_index()
print(co2_by_region_2019)
# Out:
#                        Region        2019
# 0         East Asia & Pacific  140.142667
# 1       Europe & Central Asia  286.244383
# 2   Latin America & Caribbean  100.148730
# 3  Middle East & North Africa  175.104550
# 4               North America   30.104023
# 5                  South Asia   10.304685
# 6          Sub-Saharan Africa   43.942360

# %% [markdown]
# ##### **Simple Cleaning**

# %% [markdown]
# ##### 16. Replace missing values in the year columns with `0`.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
# year_columns = ['2015', '2016', '2017', '2018', '2019', '2020']
# #If you already know the exact year columns (say, 2015 through 2020), you could also just list them directly instead of using isdigit()
# df[year_columns] = df[year_columns].fillna(0)

# OR

year_columns = [col for col in df.columns if col.isdigit()]
df[year_columns] = df[year_columns].fillna(0)

#[col for col in df.columns if col.isdigit()]
#A list comprehension that grabs only the column names that are purely numeric strings (like '2019', '2020')
#df[year_columns].fillna(0) — replaces any NaN values in those specific columns with 0.
#Assigning it back to df[year_columns] updates the DataFrame in place with the filled values.

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %% [markdown]
# ##### 17. Rename the column `Country Name` to `country_name` (no spaces).

# %%
df.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df.rename(columns = {'Country Name': 'country_name'}, inplace = True)

# %%
df.head()
# Out:
#   country_name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %% [markdown]
# ##### 18. Sort the DataFrame by `2019` values, highest to lowest.

# %%
df.head()
# Out:
#   country_name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df.sort_values(by = '2019', ascending = True)
# Out:
#              country_name country_code                      Region  \
# 0                   Aruba          ABW   Latin America & Caribbean
# 8          American Samoa          ASM         East Asia & Pacific
# 24                Bermuda          BMU               North America
# 45                Curacao          CUW   Latin America & Caribbean
# 46         Cayman Islands          CYM   Latin America & Caribbean
# ..                    ...          ...                         ...
# 28      Brunei Darussalam          BRN         East Asia & Pacific
# 5    United Arab Emirates          ARE  Middle East & North Africa
# 19                Bahrain          BHR  Middle East & North Africa
# 105                Kuwait          KWT  Middle East & North Africa
# 162                 Qatar          QAT  Middle East & North Africa
#
#                              Indicator Name       1990       1991       1992  \
# 0    CO2 emissions (metric tons per capita)   0.000000   0.000000   0.000000
# ...

# %% [markdown]
# ##### 19. Filter out rows where `2019` value is missing (`NaN`).

# %%
df.head()
# Out:
#   country_name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df[df['2019'].notna()]
# Out:
#      country_name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name      1990      1991      1992  \
# 0    CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1    CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# ...

# %% [markdown]
# ##### **Simple Visualization**

# %% [markdown]
# ##### 20. Plot a bar chart of the top 10 countries by 2019 CO2 emissions using matplotlib.

# %%
top10_2019 = df.sort_values(by='2019', ascending=False).head(10)

plt.figure(figsize=(18,6))

plt.figure(figsize=(18,6))
sns.barplot(x='country_name', y='2019', data=top10_2019, color='orange')
plt.xticks(rotation=45)
plt.show()

# OR 

# top10_2019 = df.sort_values(by='2019', ascending=False).head(10)

# plt.figure(figsize=(18,6))
# plt.bar(top10_2019['country_name'], top10_2019['2019'], color='orange')

## It's purely based on position
## 1st argument → top10_2019['country_name'] → becomes the x-axis (the categories/labels along the bottom)
## 2nd argument → top10_2019['2019'] → becomes the height of each bar, i.e., the y-axis (how tall each bar is)

# plt.xlabel('Country')
# plt.ylabel('CO2 Emissions (2019)')
# plt.title('Top 10 Countries by 2019 CO2 Emissions')
# plt.xticks(rotation=45)
# plt.show()

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

server = r"LAPTOP-A70F1ENF\SHIVASQLEXPRESS"
database = "P_CO2_emission"   # database name
driver = "ODBC Driver 17 for SQL Server"

params = quote_plus(
    f"DRIVER={{{driver}}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
)
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

df.to_sql("CO2emission", engine, if_exists="replace", index=False)   # table name

pd.read_sql("SELECT TOP 5 * FROM CO2emission;", engine)   # matches table name above
# Out:
#   country_name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)  0.000000  0.000000  0.000000
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2010      2011      2012      2013  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...
