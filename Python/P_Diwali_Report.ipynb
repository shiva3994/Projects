# %%
import pandas as pd
import numpy as nb
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Data_diwalisale.csv', encoding = 'unicode_escape')

# %% [markdown]
# ### Basic of the table

# %%
df.head(5)
# Show first 5 rows
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail(5)
# Show last 5 rows
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
df.shape
# Check shape of the table
# Out:
# (11251, 15)

# %%
df.info()
# Check info of the table
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
df.dtypes
# Types of data
# Out:
# User_ID               int64
# Cust_name               str
# Product_ID              str
# Gender                  str
# Age Group               str
# Age                   int64
# Marital_Status        int64
# State                   str
# Zone                    str
# Occupation              str
# Product_Category        str
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.describe()
# Describe the details of the table
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
print('Total length of the table is:',len(df))
# Out:
# Total length of the table is: 11251

# %% [markdown]
# ### Understand data Structure

# %%
df.shape
# Out:
# (11251, 15)

# %%
print('Shape of the dataset is:', df.shape)
# Out:
# Shape of the dataset is: (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %%
print('Shape of the columns is:', df.columns)
# Out:
# Shape of the columns is: Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %%
df.info()
# show the column names and datatype
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %% [markdown]
# ### Missing value and Anamolous detection

# %%
df.isnull()
# check for null
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
df.isnull().sum()
# check for sum of null columnwise
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
null_counts = null_counts[null_counts > 0]
null_counts
# show column containing nullhaving value above 0
# Out:
# Amount         12
# Status      11251
# unnamed1    11251
# dtype: int64

# %%
plt.figure(figsize=(10,5))
null_counts.plot(kind='bar',color='green')

plt.title('Missing value per column') # title
plt.xlabel('Column name') # X axis name
plt.ylabel('Number of missing values') # Y axis name

plt.xticks(rotation = 40)
plt.yticks(rotation = 40)

plt.show() # show final graph

# %%
cat_cols = ['Status','unnamed1']
for col in cat_cols:
    df[col] = df[col].fillna('unknown')
# Resolve the categorical with unknown

num_cols = ['Amount']
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())
# Resolve the numerical with median

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount   Status unnamed1
# 0  23952.0  unknown  unknown
# 1  23934.0  unknown  unknown
# ...

# %%
df.isnull().sum()
# after removing null check
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# Status              0
# unnamed1            0
# dtype: int64

# %%
print('Duplicate rows:', df.duplicated().sum())
# check duplkicate
# Out:
# Duplicate rows: 8

# %%
df = df.drop_duplicates()
# remove duplicates

# %%
print('Shape after removing duplicate:', df.shape)
# Out:
# Shape after removing duplicate: (11243, 15)

# %%
df['Age'].mean()
# Out:
# np.float64(35.42284087876901)

# %%
df['Age'].min()
# Out:
# np.int64(12)

# %%
df['Age'].max()
# Out:
# np.int64(92)

# %%
print('Average age is :', round(df['Age'].mean(),2))
# Out:
# Average age is : 35.42

# %%
print('Min age is :', round(df["Age"].min(),2))
# Out:
# Min age is : 12

# %%
print('Max age is :',df['Age'].max())
# Out:
# Max age is : 92

# %%
State = df['State'].unique()

print('List of unique states :',len(State))

print(State)
# Out:
# List of unique states : 16
# <StringArray>
# [     'Maharashtra',   'Andhra Pradesh',    'Uttar Pradesh',
#         'Karnataka',          'Gujarat', 'Himachal Pradesh',
#             'Delhi',   'Madhya Pradesh',        'Jharkhand',
#            'Kerala',          'Haryana',            'Bihar',
#         'Rajasthan',      'Uttarakhand',        'Telangana',
#            'Punjab']
# Length: 16, dtype: str

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7838
# M    3405
# Name: count, dtype: int64

# %%
# Manual Effort
# Plotting a bar chart for Gender and it's count

plt.figure(figsize=(8,5))

counts = df['Gender'].value_counts()

plt.bar(counts.index,counts.values, color = 'seagreen')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')

plt.show()

# %%
# Automation
# Plotting a bar chart for Gender and it's count

counts_a = sns.countplot(x = 'Gender', data = df, color = 'orange')
# sns.countplot(): Creates a bar chart using Seaborn that counts occurrences of each unique value in the specified column.
# x = 'Gender': Places the distinct values from the 'Gender' column (e.g., "Male", "Female") on the horizontal X-axis.
# data = df: Tells Seaborn to pull the 'Gender' column from your pandas DataFrame named df.
# counts_a = .: Stores the created plot object (a matplotlib Axes) into the variable counts_a.


for bars in counts_a.containers:
    counts_a.bar_label(bars)
# "Go through every group of bars on my chart (counts_a.containers), and slap a clear number label on top of each individual bar (counts_a.bar_label)."

# %%
# Plotting a bar chart for gender vs total amount

sales_by_gender = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)


sns.barplot(x = 'Gender', y = 'Amount', data = sales_by_gender, color = 'Orange')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
sales_by_age = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in sales_by_age.containers:
    sales_by_age.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age, color = 'orange')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
# total number of orders from top 10 states
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders', color = 'orange')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
ax = sns.countplot(data = df, x = 'Marital_Status', color = 'orange')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Occupation
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation',color='orange')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
#Product Category
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category', color = 'orange')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()
