# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('Data_ToP250movie_imdb2026.csv')

# %%
df.head()
# Out:
#           Id                                    Url  \
# 0  tt0111161  https://www.imdb.com/title/tt0111161/
# 1  tt0068646  https://www.imdb.com/title/tt0068646/
# 2  tt0468569  https://www.imdb.com/title/tt0468569/
# 3  tt0071562  https://www.imdb.com/title/tt0071562/
# 4  tt0167260  https://www.imdb.com/title/tt0167260/
#
#                                     Primarytitle  \
# 0                       The Shawshank Redemption
# 1                                  The Godfather
# 2                                The Dark Knight
# 3                          The Godfather Part II
# 4  The Lord of the Rings: The Return of the King
#
#                                    Originaltitle   Type  \
# 0                       The Shawshank Redemption  movie
# 1                                  The Godfather  movie
# 2                                The Dark Knight  movie
# 3                          The Godfather Part II  movie
# 4  The Lord of the Rings: The Return of the King  movie
#
#                                          Description  \
# 0  After a banker is sentenced to life in Shawsha...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  Gandalf and Aragorn lead the World of Men agai...
#
#                                         Primaryimage  \
# 0  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 1  https://m.media-amazon.com/images/M/MV5BNGEwYj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMDIxMz...
# 4  https://m.media-amazon.com/images/M/MV5BMTZkMj...
#
#                                           Thumbnails  \
# 0  [{'url': 'https://m.media-amazon.com/images/M/...
# 1  [{'url': 'https://m.media-amazon.com/images/M/...
# 2  [{'url': 'https://m.media-amazon.com/images/M/...
# 3  [{'url': 'https://m.media-amazon.com/images/M/...
# 4  [{'url': 'https://m.media-amazon.com/images/M/...
#
#                                        Trailer Contentrating  ...  \
# 0  https://www.youtube.com/watch?v=xyXX8LXiNJ4             R  ...
# 1  https://www.youtube.com/watch?v=8V2k2YQEQJ4             R  ...
# 2  https://www.youtube.com/watch?v=kmJLuwP3MbY         PG-13  ...
# 3  https://www.youtube.com/watch?v=9O1Iy9od7-A             R  ...
# 4  https://www.youtube.com/watch?v=zckJCxYxn1g         PG-13  ...
#
#                                     Filminglocations  \
# 0                              ['Butler, Ohio, USA']
# 1           ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2                         ['Chicago, Illinois, USA']
# 3  ['Kaiser Estate - 4000 W Lake Blvd, Homewood, ...
# 4  ['Hinuera Valley, Matamata, Waikato, New Zeala...
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 3  [{'id': 'co0023400', 'name': 'Paramount Pictur...   13000000.0
# 4  [{'id': 'co0046718', 'name': 'New Line Cinema'...   94000000.0
#
#   Grossworldwide                             Genres Isadult Runtimeminutes  \
# 0   2.942491e+07                          ['Drama']   False            142
# 1   2.509334e+08                 ['Crime', 'Drama']   False            175
# 2   1.008480e+09              ['Crime', 'Thriller']   False            152
# 3   4.820954e+07                 ['Crime', 'Drama']   False            202
# 4   1.149454e+09  ['Adventure', 'Drama', 'Fantasy']   False            201
#
#   Averagerating Numvotes  Metascore
# 0           9.3  3219026       82.0
# 1           9.2  2244201      100.0
# 2           9.1  3204629       85.0
# 3           9.0  1505420       90.0
# 4           9.0  2181632       94.0
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   250 non-null    str
#  1   Url                  250 non-null    str
#  2   Primarytitle         250 non-null    str
#  3   Originaltitle        250 non-null    str
#  4   Type                 250 non-null    str
#  5   Description          250 non-null    str
#  6   Primaryimage         250 non-null    str
#  7   Thumbnails           250 non-null    str
#  8   Trailer              243 non-null    str
#  9   Contentrating        244 non-null    str
#  10  Startyear            250 non-null    int64
#  11  Endyear              0 non-null      float64
#  12  Releasedate          249 non-null    str
#  13  Interests            250 non-null    str
#  14  Countriesoforigin    250 non-null    str
#  15  Externallinks        250 non-null    str
#  16  Spokenlanguages      250 non-null    str
#  17  Filminglocations     250 non-null    str
#  18  Productioncompanies  250 non-null    str
#  19  Budget               226 non-null    float64
#  20  Grossworldwide       246 non-null    float64
#  21  Genres               250 non-null    str
#  22  Isadult              250 non-null    bool
#  23  Runtimeminutes       250 non-null    int64
#  24  Averagerating        250 non-null    float64
#  25  Numvotes             250 non-null    int64
#  26  Metascore            232 non-null    float64
# dtypes: bool(1), float64(5), int64(3), str(18)
# memory usage: 51.2 KB

# %%
df.describe()
# Out:
#          Startyear  Endyear        Budget  Grossworldwide  Runtimeminutes  \
# count   250.000000      0.0  2.260000e+02    2.460000e+02      250.000000
# mean   1989.448000      NaN  1.809864e+08    2.426270e+08      131.736000
# std      25.557387      NaN  1.210412e+09    3.789378e+08       34.503744
# min    1921.000000      NaN  1.330000e+05    2.951000e+03       45.000000
# 25%    1973.250000      NaN  3.300000e+06    1.149137e+07      109.250000
# 50%    1996.500000      NaN  1.800000e+07    6.612008e+07      128.500000
# 75%    2009.000000      NaN  6.300000e+07    3.477131e+08      147.750000
# max    2026.000000      NaN  1.500000e+10    2.799439e+09      374.000000
#
#        Averagerating      Numvotes   Metascore
# count     250.000000  2.500000e+02  232.000000
# mean        8.314400  7.701809e+05   82.702586
# std         0.233088  6.315718e+05   11.022307
# min         8.000000  2.579100e+04   55.000000
# 25%         8.100000  2.514288e+05   75.000000
# 50%         8.200000  6.187955e+05   85.000000
# 75%         8.400000  1.160524e+06   91.000000
# max         9.300000  3.219026e+06  100.000000

# %%
print(df.columns.tolist())
# Out:
# ['Id', 'Url', 'Primarytitle', 'Originaltitle', 'Type', 'Description', 'Primaryimage', 'Thumbnails', 'Trailer', 'Contentrating', 'Startyear', 'Endyear', 'Releasedate', 'Interests', 'Countriesoforigin', 'Externallinks', 'Spokenlanguages', 'Filminglocations', 'Productioncompanies', 'Budget', 'Grossworldwide', 'Genres', 'Isadult', 'Runtimeminutes', 'Averagerating', 'Numvotes', 'Metascore']

# %% [markdown]
# ##### Dropping the unwanted columns

# %%
cols = ['Url', 'Description', 'Primaryimage','Thumbnails', 'Trailer', 'Endyear','Externallinks']

# %%
df.drop(cols, axis = 1, inplace = True)

# %%
df.head()
# Out:
#           Id                                   Primarytitle  \
# 0  tt0111161                       The Shawshank Redemption
# 1  tt0068646                                  The Godfather
# 2  tt0468569                                The Dark Knight
# 3  tt0071562                          The Godfather Part II
# 4  tt0167260  The Lord of the Rings: The Return of the King
#
#                                    Originaltitle   Type Contentrating  \
# 0                       The Shawshank Redemption  movie             R
# 1                                  The Godfather  movie             R
# 2                                The Dark Knight  movie         PG-13
# 3                          The Godfather Part II  movie             R
# 4  The Lord of the Rings: The Return of the King  movie         PG-13
#
#    Startyear Releasedate                                          Interests  \
# 0       1994  14-10-1994  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...
# 1       1972  24-03-1972  ['Epic', 'Gangster', 'Psychological Drama', 'T...
# 2       2008  18-07-2008  ['DC', 'Action Epic', 'Epic', 'Psychological D...
# 3       1974  18-12-1974  ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama']
# 4       2003  17-12-2003  ['The Lord of the Rings', 'Action Epic', 'Adve...
#
#   Countriesoforigin           Spokenlanguages  \
# 0            ['US']                    ['en']
# 1            ['US']        ['en', 'it', 'la']
# 2      ['US', 'GB']                    ['en']
# 3            ['US']  ['en', 'it', 'es', 'la']
# 4      ['NZ', 'US']                    ['en']
#
#                                     Filminglocations  \
# 0                              ['Butler, Ohio, USA']
# 1           ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2                         ['Chicago, Illinois, USA']
# 3  ['Kaiser Estate - 4000 W Lake Blvd, Homewood, ...
# 4  ['Hinuera Valley, Matamata, Waikato, New Zeala...
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 3  [{'id': 'co0023400', 'name': 'Paramount Pictur...   13000000.0
# 4  [{'id': 'co0046718', 'name': 'New Line Cinema'...   94000000.0
#
#    Grossworldwide                             Genres  Isadult  Runtimeminutes  \
# 0    2.942491e+07                          ['Drama']    False             142
# 1    2.509334e+08                 ['Crime', 'Drama']    False             175
# 2    1.008480e+09              ['Crime', 'Thriller']    False             152
# 3    4.820954e+07                 ['Crime', 'Drama']    False             202
# 4    1.149454e+09  ['Adventure', 'Drama', 'Fantasy']    False             201
#
#    Averagerating  Numvotes  Metascore
# 0            9.3   3219026       82.0
# 1            9.2   2244201      100.0
# 2            9.1   3204629       85.0
# 3            9.0   1505420       90.0
# 4            9.0   2181632       94.0

# %% [markdown]
# ##### Updating date columns format

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   250 non-null    str
#  1   Primarytitle         250 non-null    str
#  2   Originaltitle        250 non-null    str
#  3   Type                 250 non-null    str
#  4   Contentrating        244 non-null    str
#  5   Startyear            250 non-null    int64
#  6   Releasedate          249 non-null    str
#  7   Interests            250 non-null    str
#  8   Countriesoforigin    250 non-null    str
#  9   Spokenlanguages      250 non-null    str
#  10  Filminglocations     250 non-null    str
#  11  Productioncompanies  250 non-null    str
#  12  Budget               226 non-null    float64
#  13  Grossworldwide       246 non-null    float64
#  14  Genres               250 non-null    str
#  15  Isadult              250 non-null    bool
#  16  Runtimeminutes       250 non-null    int64
#  17  Averagerating        250 non-null    float64
#  18  Numvotes             250 non-null    int64
#  19  Metascore            232 non-null    float64
# dtypes: bool(1), float64(4), int64(3), str(12)
# memory usage: 37.5 KB

# %%
#Converting the Startyear column to year format ( int )

df['Startyear'] = pd.to_datetime(df['Startyear'])
df['Startyear'] = df['Startyear'].dt.year

# %%
#Changing the datatype of Releasedate column to datetime format

df['Releasedate'] = pd.to_datetime(df['Releasedate'])
# Out:
# C:\Users\Shiva Thakur\AppData\Local\Temp\ipykernel_30108\1172488962.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Releasedate'] = pd.to_datetime(df['Releasedate'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   250 non-null    str
#  1   Primarytitle         250 non-null    str
#  2   Originaltitle        250 non-null    str
#  3   Type                 250 non-null    str
#  4   Contentrating        244 non-null    str
#  5   Startyear            250 non-null    int32
#  6   Releasedate          249 non-null    datetime64[us]
#  7   Interests            250 non-null    str
#  8   Countriesoforigin    250 non-null    str
#  9   Spokenlanguages      250 non-null    str
#  10  Filminglocations     250 non-null    str
#  11  Productioncompanies  250 non-null    str
#  12  Budget               226 non-null    float64
#  13  Grossworldwide       246 non-null    float64
#  14  Genres               250 non-null    str
#  15  Isadult              250 non-null    bool
#  16  Runtimeminutes       250 non-null    int64
#  17  Averagerating        250 non-null    float64
#  18  Numvotes             250 non-null    int64
#  19  Metascore            232 non-null    float64
# dtypes: bool(1), datetime64[us](1), float64(4), int32(1), int64(2), str(11)
# memory usage: 36.5 KB

# %% [markdown]
# ##### ******

# %% [markdown]
# ##### 1. Ratings distribution – What does the distribution of Averagerating look like across the Top 250?

# %%
ratings_distribution = df['Averagerating'].value_counts()

plt.figure(figsize=(15,6))
sns.barplot(x=ratings_distribution.index, y=ratings_distribution.values, color='orange')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# OR

# plt.figure(figsize=(10,6))
# sns.histplot(df['Averagerating'], bins=30, palette = 'blue')
# plt.title('Distribution of Average Ratings (Top 250 Movies)')
# plt.xlabel('Average Rating')
# plt.ylabel('Count')
# plt.show()

# %% [markdown]
# ##### Ratings are highly clustered at 8.1 - 8.5

# %% [markdown]
# ##### ******

# %% [markdown]
# ##### 2. Genre popularity – Which genres appear most often in the Top 250?

# %%
df.head()
# Out:
#           Id                                   Primarytitle  \
# 0  tt0111161                       The Shawshank Redemption
# 1  tt0068646                                  The Godfather
# 2  tt0468569                                The Dark Knight
# 3  tt0071562                          The Godfather Part II
# 4  tt0167260  The Lord of the Rings: The Return of the King
#
#                                    Originaltitle   Type Contentrating  \
# 0                       The Shawshank Redemption  movie             R
# 1                                  The Godfather  movie             R
# 2                                The Dark Knight  movie         PG-13
# 3                          The Godfather Part II  movie             R
# 4  The Lord of the Rings: The Return of the King  movie         PG-13
#
#    Startyear Releasedate                                          Interests  \
# 0       1970  1994-10-14  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...
# 1       1970  1972-03-24  ['Epic', 'Gangster', 'Psychological Drama', 'T...
# 2       1970  2008-07-18  ['DC', 'Action Epic', 'Epic', 'Psychological D...
# 3       1970  1974-12-18  ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama']
# 4       1970  2003-12-17  ['The Lord of the Rings', 'Action Epic', 'Adve...
#
#   Countriesoforigin           Spokenlanguages  \
# 0            ['US']                    ['en']
# 1            ['US']        ['en', 'it', 'la']
# 2      ['US', 'GB']                    ['en']
# 3            ['US']  ['en', 'it', 'es', 'la']
# 4      ['NZ', 'US']                    ['en']
#
#                                     Filminglocations  \
# 0                              ['Butler, Ohio, USA']
# 1           ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2                         ['Chicago, Illinois, USA']
# 3  ['Kaiser Estate - 4000 W Lake Blvd, Homewood, ...
# 4  ['Hinuera Valley, Matamata, Waikato, New Zeala...
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 3  [{'id': 'co0023400', 'name': 'Paramount Pictur...   13000000.0
# 4  [{'id': 'co0046718', 'name': 'New Line Cinema'...   94000000.0
#
#    Grossworldwide                             Genres  Isadult  Runtimeminutes  \
# 0    2.942491e+07                          ['Drama']    False             142
# 1    2.509334e+08                 ['Crime', 'Drama']    False             175
# 2    1.008480e+09              ['Crime', 'Thriller']    False             152
# 3    4.820954e+07                 ['Crime', 'Drama']    False             202
# 4    1.149454e+09  ['Adventure', 'Drama', 'Fantasy']    False             201
#
#    Averagerating  Numvotes  Metascore
# 0            9.3   3219026       82.0
# 1            9.2   2244201      100.0
# 2            9.1   3204629       85.0
# 3            9.0   1505420       90.0
# 4            9.0   2181632       94.0

# %%
# Split geners in list and explode our data frame to have one genre per row for each movie
df['Genres'] = df['Genres'].str.strip("[]'\"").str.split("', '")

# %%
#The explode function is used to transform each element of a list-like to a row, replicating the index values. 
#Here, it is used to create a new row for each genre in the 'Genre' column.
df = df.explode('Genres').reset_index(drop = True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   632 non-null    str
#  1   Primarytitle         632 non-null    str
#  2   Originaltitle        632 non-null    str
#  3   Type                 632 non-null    str
#  4   Contentrating        618 non-null    str
#  5   Startyear            632 non-null    int32
#  6   Releasedate          631 non-null    datetime64[us]
#  7   Interests            632 non-null    str
#  8   Countriesoforigin    632 non-null    str
#  9   Spokenlanguages      632 non-null    str
#  10  Filminglocations     632 non-null    str
#  11  Productioncompanies  632 non-null    str
#  12  Budget               577 non-null    float64
#  13  Grossworldwide       624 non-null    float64
#  14  Genres               632 non-null    str
#  15  Isadult              632 non-null    bool
#  16  Runtimeminutes       632 non-null    int64
#  17  Averagerating        632 non-null    float64
#  18  Numvotes             632 non-null    int64
#  19  Metascore            589 non-null    float64
# dtypes: bool(1), datetime64[us](1), float64(4), int32(1), int64(2), str(11)
# memory usage: 92.1 KB

# %%
# Casting column Geners to Category instead of Str

df['Genres'] = df['Genres'].astype('category')
df['Genres'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Biography', 'Comedy',
#                   'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir',
#                   'History', 'Horror', 'Music', 'Musical', 'Mystery',
#                   'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=str)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   632 non-null    str
#  1   Primarytitle         632 non-null    str
#  2   Originaltitle        632 non-null    str
#  3   Type                 632 non-null    str
#  4   Contentrating        618 non-null    str
#  5   Startyear            632 non-null    int32
#  6   Releasedate          631 non-null    datetime64[us]
#  7   Interests            632 non-null    str
#  8   Countriesoforigin    632 non-null    str
#  9   Spokenlanguages      632 non-null    str
#  10  Filminglocations     632 non-null    str
#  11  Productioncompanies  632 non-null    str
#  12  Budget               577 non-null    float64
#  13  Grossworldwide       624 non-null    float64
#  14  Genres               632 non-null    category
#  15  Isadult              632 non-null    bool
#  16  Runtimeminutes       632 non-null    int64
#  17  Averagerating        632 non-null    float64
#  18  Numvotes             632 non-null    int64
#  19  Metascore            589 non-null    float64
# dtypes: bool(1), category(1), datetime64[us](1), float64(4), int32(1), int64(2), str(10)
# memory usage: 87.9 KB

# %%
df.head()
# Out:
#           Id              Primarytitle             Originaltitle   Type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0068646             The Godfather             The Godfather  movie
# 3  tt0468569           The Dark Knight           The Dark Knight  movie
# 4  tt0468569           The Dark Knight           The Dark Knight  movie
#
#   Contentrating  Startyear Releasedate  \
# 0             R       1970  1994-10-14
# 1             R       1970  1972-03-24
# 2             R       1970  1972-03-24
# 3         PG-13       1970  2008-07-18
# 4         PG-13       1970  2008-07-18
#
#                                            Interests Countriesoforigin  \
# 0  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...            ['US']
# 1  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 2  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 3  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
# 4  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
#
#       Spokenlanguages                          Filminglocations  \
# 0              ['en']                     ['Butler, Ohio, USA']
# 1  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 3              ['en']                ['Chicago, Illinois, USA']
# 4              ['en']                ['Chicago, Illinois, USA']
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 3  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 4  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
#
#    Grossworldwide    Genres  Isadult  Runtimeminutes  Averagerating  Numvotes  \
# 0    2.942491e+07     Drama    False             142            9.3   3219026
# 1    2.509334e+08     Crime    False             175            9.2   2244201
# 2    2.509334e+08     Drama    False             175            9.2   2244201
# 3    1.008480e+09     Crime    False             152            9.1   3204629
# 4    1.008480e+09  Thriller    False             152            9.1   3204629
#
#    Metascore
# 0       82.0
# 1      100.0
# 2      100.0
# 3       85.0
# 4       85.0

# %%
sns.catplot(y = 'Genres',
            data = df,
            kind = 'count',
            color = 'orange',
            order = df['Genres'].value_counts().index)

plt.title('Count by Genre')
plt.xlabel('Count')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# ##### Drama, Comedy and Action are top 3 geners in Top 250

# %% [markdown]
# ##### ******

# %% [markdown]
# ##### 3. Budget vs. rating – Does spending more money make a better movie?

# %%
df.head()
# Out:
#           Id              Primarytitle             Originaltitle   Type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0068646             The Godfather             The Godfather  movie
# 3  tt0468569           The Dark Knight           The Dark Knight  movie
# 4  tt0468569           The Dark Knight           The Dark Knight  movie
#
#   Contentrating  Startyear Releasedate  \
# 0             R       1970  1994-10-14
# 1             R       1970  1972-03-24
# 2             R       1970  1972-03-24
# 3         PG-13       1970  2008-07-18
# 4         PG-13       1970  2008-07-18
#
#                                            Interests Countriesoforigin  \
# 0  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...            ['US']
# 1  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 2  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 3  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
# 4  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
#
#       Spokenlanguages                          Filminglocations  \
# 0              ['en']                     ['Butler, Ohio, USA']
# 1  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 3              ['en']                ['Chicago, Illinois, USA']
# 4              ['en']                ['Chicago, Illinois, USA']
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 3  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 4  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
#
#    Grossworldwide    Genres  Isadult  Runtimeminutes  Averagerating  Numvotes  \
# 0    2.942491e+07     Drama    False             142            9.3   3219026
# 1    2.509334e+08     Crime    False             175            9.2   2244201
# 2    2.509334e+08     Drama    False             175            9.2   2244201
# 3    1.008480e+09     Crime    False             152            9.1   3204629
# 4    1.008480e+09  Thriller    False             152            9.1   3204629
#
#    Metascore
# 0       82.0
# 1      100.0
# 2      100.0
# 3       85.0
# 4       85.0

# %%
df_clean = df[df['Budget'] < 5e8]  
# remove bad currency-mixed values mostly in case of USD

#OR

# More defensible: only drop rows that are BOTH unrealistically high AND non-US
# mask = (df['Budget'] >= 5e8) & (~df['Countriesoforigin'].str.contains("'US'"))
# df_clean = df[~mask]

plt.figure(figsize = (20,8))

sns.scatterplot(x='Budget', y='Averagerating', hue='Genres', data=df_clean, alpha=0.8, s=80)
sns.regplot(x='Budget', y='Averagerating', data=df_clean, scatter = False, color='black', line_kws={'linestyle':'--'})

plt.title('Budget vs. IMDb Rating, colored by Genre')
plt.xlabel('Budget (USD)')
plt.ylabel('Average Rating')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# Bucket by budget range for a clearer comparison
# df_clean['Budget_bucket'] = pd.cut(df_clean['Budget'],
#     bins=[0, 10e6, 50e6, 100e6, 200e6, 500e6],
#     labels=['<$10M','$10-50M','$50-100M','$100-200M','$200-500M'])
# df_clean.groupby('Budget_bucket', observed=True)['Averagerating'].mean().plot(kind='bar')
# plt.title('Average Rating by Budget Range')
# plt.ylabel('Average Rating')
# plt.show()

# %%
df_clean[['Budget','Averagerating']].corr()
# Out:
#                  Budget  Averagerating
# Budget         1.000000       0.122334
# Averagerating  0.122334       1.000000

# %% [markdown]
# ##### Spending more doesn't make critics/audiences rate a movie higher.

# %% [markdown]
# ##### ******

# %% [markdown]
# ##### 4. Budget vs. box office – Does a bigger budget guarantee bigger box office returns?

# %%
df.head()
# Out:
#           Id              Primarytitle             Originaltitle   Type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0068646             The Godfather             The Godfather  movie
# 3  tt0468569           The Dark Knight           The Dark Knight  movie
# 4  tt0468569           The Dark Knight           The Dark Knight  movie
#
#   Contentrating  Startyear Releasedate  \
# 0             R       1970  1994-10-14
# 1             R       1970  1972-03-24
# 2             R       1970  1972-03-24
# 3         PG-13       1970  2008-07-18
# 4         PG-13       1970  2008-07-18
#
#                                            Interests Countriesoforigin  \
# 0  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...            ['US']
# 1  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 2  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 3  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
# 4  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
#
#       Spokenlanguages                          Filminglocations  \
# 0              ['en']                     ['Butler, Ohio, USA']
# 1  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 3              ['en']                ['Chicago, Illinois, USA']
# 4              ['en']                ['Chicago, Illinois, USA']
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 3  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 4  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
#
#    Grossworldwide    Genres  Isadult  Runtimeminutes  Averagerating  Numvotes  \
# 0    2.942491e+07     Drama    False             142            9.3   3219026
# 1    2.509334e+08     Crime    False             175            9.2   2244201
# 2    2.509334e+08     Drama    False             175            9.2   2244201
# 3    1.008480e+09     Crime    False             152            9.1   3204629
# 4    1.008480e+09  Thriller    False             152            9.1   3204629
#
#    Metascore
# 0       82.0
# 1      100.0
# 2      100.0
# 3       85.0
# 4       85.0

# %%
plt.figure(figsize = (20,8))

sns.scatterplot(x='Budget', y='Grossworldwide', hue='Genres', data=df_clean, alpha=0.8, s=80)
sns.regplot(x='Budget', y='Grossworldwide', data=df_clean, scatter=False, color='black', line_kws={'linestyle':'--'})

plt.title('Budget vs. Box office, colored by Genre')
plt.xlabel('Budget (USD)')
plt.ylabel('Gross World Wide (USD)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
df_clean[['Budget','Grossworldwide']].corr()
# Out:
#                   Budget  Grossworldwide
# Budget          1.000000        0.751358
# Grossworldwide  0.751358        1.000000

# %% [markdown]
# ##### Spending more tends to mean earning more.

# %% [markdown]
# ##### ******

# %% [markdown]
# ##### 5. Runtime trends over time – Have movies gotten longer over the decades?

# %%
df.head()
# Out:
#           Id              Primarytitle             Originaltitle   Type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0068646             The Godfather             The Godfather  movie
# 3  tt0468569           The Dark Knight           The Dark Knight  movie
# 4  tt0468569           The Dark Knight           The Dark Knight  movie
#
#   Contentrating  Startyear Releasedate  \
# 0             R       1970  1994-10-14
# 1             R       1970  1972-03-24
# 2             R       1970  1972-03-24
# 3         PG-13       1970  2008-07-18
# 4         PG-13       1970  2008-07-18
#
#                                            Interests Countriesoforigin  \
# 0  ['Epic', 'Period Drama', 'Prison Drama', 'Psyc...            ['US']
# 1  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 2  ['Epic', 'Gangster', 'Psychological Drama', 'T...            ['US']
# 3  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
# 4  ['DC', 'Action Epic', 'Epic', 'Psychological D...      ['US', 'GB']
#
#       Spokenlanguages                          Filminglocations  \
# 0              ['en']                     ['Butler, Ohio, USA']
# 1  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 2  ['en', 'it', 'la']  ["Forza d'Agrò, Messina, Sicily, Italy"]
# 3              ['en']                ['Chicago, Illinois, USA']
# 4              ['en']                ['Chicago, Illinois, USA']
#
#                                  Productioncompanies       Budget  \
# 0  [{'id': 'co0040620', 'name': 'Castle Rock Ente...   25000000.0
# 1  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 2  [{'id': 'co0023400', 'name': 'Paramount Pictur...    6000000.0
# 3  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
# 4  [{'id': 'co0002663', 'name': 'Warner Bros.'}, ...  185000000.0
#
#    Grossworldwide    Genres  Isadult  Runtimeminutes  Averagerating  Numvotes  \
# 0    2.942491e+07     Drama    False             142            9.3   3219026
# 1    2.509334e+08     Crime    False             175            9.2   2244201
# 2    2.509334e+08     Drama    False             175            9.2   2244201
# 3    1.008480e+09     Crime    False             152            9.1   3204629
# 4    1.008480e+09  Thriller    False             152            9.1   3204629
#
#    Metascore
# 0       82.0
# 1      100.0
# 2      100.0
# 3       85.0
# 4       85.0

# %%
# (Line chart of average `Runtimeminutes` by decade, using `Startyear`.)

# %%
# 5. **Runtime trends over time** – Have movies gotten longer over the decades? 
# (Line chart of average `Runtimeminutes` by decade, using `Startyear`.)

# 6. **Votes vs. rating** – Do more popular (highly-voted) movies tend to rate higher, or is popularity independent of quality? 
# (Scatter plot of `Numvotes` vs. `Averagerating`, log-scale on votes since the range is huge.)

# 7. **Country of origin breakdown** – Which countries produce the most Top-250-caliber films? 
# (Parse `Countriesoforigin`, plot a bar chart or pie chart of movie counts per country.)
